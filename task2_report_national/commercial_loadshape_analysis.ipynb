# %% [markdown]
# # Loadshape Electrification Analysis for Commercial Sector by State
# ## Using NREL's ComStock, 2023 release of amy_2018_v1

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import calendar
import datetime as dt
import seaborn as sns
sns.set_theme()

from sg2t.io.loadshapes.nrel.api import API
from sg2t.io.loadshapes.nrel.naming import BUILDING_TYPES
from sg2t.utils.timeseries import Timeseries

from analysis_utils import format_columns_df, sigmoid, loadshape_analysis

# %% [markdown]
# # Loop over: years, states, building types

# %%
sector = "Comstock"

# %%
year_range = np.arange(2023, 2051)

# %%
data_model_year = 2018 # does not vary for this study

# %% [markdown]
# ## Get data for all top states
# - Residential:  New York, Illinois, California, Ohio, Michigan, Texas, Pennsylvania, and Massachusetts
# - Commercial: New York, Illinois, California, Ohio, Michigan, Texas, Pennsylvania, and Florida
#
# Divide states into three categories:
# - those with a set target year and that have started adopting: CA, NY, MA, IL, MI, FL
# - those with a set target year and will adopt: PA?
# - those that have no target set (follow the market): OH, TX

# %% [markdown]
# ## Import input values

# %%
with open('inputs.json', 'r') as openfile:
     inputs = json.load(openfile)

# %%
com_states = list(inputs["State Target Year"].keys())

# %%
state_start_year = inputs["State Start Year"]
state_target_year = inputs["State Target Year"]
states_tz =  inputs["State Timezone"]
state_heater_year =  inputs["State Heater Year"]
state_water_year =  inputs["State Water Year"]
state_cooling_year =  inputs["State Cooling Year"]
state_ie_year =  inputs["State Interior Equipment Year"]
state_heater_AR =  inputs["State Heater AR"]
state_water_AR =  inputs["State Water AR"]
state_cooling_AR =  inputs["State Cooling AR"]
state_ie_AR =  inputs["State Interior Equipment AR"]

# %% [markdown]
# ## Import NREL Stock data and format (for all states and building types)
# #### Note that this dataset is missing some building types data for RI and VT
# If not cached it will pull from NREL API

# %%
api = API()
data = {}

for state in com_states:
    print(state)
    
    for btype in BUILDING_TYPES:
        filename = f"./nrel_data_2023/{sector}_{state}_{btype}.csv"
        if not os.path.exists(filename):
        
            # Download data
            try:
                df = api.get_data_comstock_by_state(state, btype)
            except:
                continue # skip missing data and just add what is found
            df = format_columns_df(df)

            # Save locally
            try:
                df.to_csv(filename)
            except OSError:
                os.mkdir("./nrel_data_2023")
                df.to_csv(filename)
            

        # Load cached data
        df = pd.read_csv(f"./nrel_data_2023/{sector}_{state}_{btype}.csv")
        df["Datetime"] = Timeseries.make_datetime(df["timestamp"])
        df = df.drop("timestamp", axis=1)
        df.sort_values("Datetime", inplace=True, ascending=True)
        df.set_index("Datetime", inplace=True, drop=True)
        data[f"{state}_{btype}"] = df
        if 'Propane Heating' in df.columns or 'Fuel Oil Heating' in df.columns:
            print(state, btype, df.columns)
# Out:
# NY
# CA
# IL
# OH
# MI
# TX
# PA
# MA
# FL
# AL
# AR
# AZ
# CO
# CT
# DC
# DE
# GA
# IA
# ID
# IN
# KS
# KY
# LA
# MD
# ME
# MN
# MO
# MS
# MT
# NC
# ND
# NE
# NH
# NJ
# NM
# NV
# OK
# OR
# RI
# SC
# SD
# TN
# UT
# VA
# VT
# WA
# WI
# WV
# WY

# %% [markdown]
# ## Start loop to get new supply for each state and building types

# %%
results_comm = {} # Structure: results_comm[str_study_year][state][btype]

# %%
plot_sigmoids = False

# %%
for study_year in [2050]:
    str_study_year = str(study_year)
    
    for state in ["CA", "NY", "TX", "OH", "NV"]:
        print(state)
        
        # Set params for each state
        # Start year of electrification adoption
        start_year = state_start_year[state]
        # Target year
        target_year = state_target_year[state]
        # Peak adoption year per end use
        heater_year, water_year, cooling_year, ie_year = state_heater_year[state], state_water_year[state], state_cooling_year[state], state_ie_year[state]
        # Adoption rate per end use
        heater_AR, water_AR, cooling_AR, ie_AR = state_heater_AR[state], state_water_AR[state], state_cooling_AR[state], state_ie_AR[state]


        aggregation = "avg" # "avg" or "peak_day"
        month_start = 1
        month_end = 12
        day_type = None
        timezone = states_tz[state]
        

        for btype in ['largeoffice']:
            try:
                df = data[f"{state}_{btype}"]
            except KeyError:
                if state=="RI" or state=="VT" or state=="DC":
                    continue
                else:
                    raise

            comstock_heating = df[['Other Fuel Heating', 'Natural Gas Heating']].sum(axis=1)
            comstock_water_heating = df[['Other Fuel Water Heating', 'Natural Gas Water Heating']].sum(axis=1)
            comstock_cooling = df[['Other Fuel Cooling', 'Natural Gas Cooling']].sum(axis=1)
            comstock_ie = df[['Other Fuel Interior Equipment', 'Natural Gas Interior Equipment']].sum(axis=1)

            appliance = [comstock_heating, comstock_water_heating, comstock_cooling, comstock_ie]
            
            # Generate x values
            x = np.arange(start_year, target_year + 1, 1)
            print(x)
            #x = np.linspace(start_year, target_year, 100)

            new_sup = np.zeros((len(x),4))
            final_val = np.zeros((len(x),4))
            X0 = [heater_year, water_year, cooling_year, ie_year]
            K = [heater_AR, water_AR, cooling_AR, ie_AR]


            # Applying arithmetic or geometric growth rate to achieve electrification
            
            for i in range(len(appliance)):
                # Initial and target value
                initial_value = appliance[i].sum()

                # Calculate parameters
                x0 = X0[i]
                k = K[i]/100  # adjust this to suit your needs

                new_sup[:,i] = sigmoid(x, 1, k, x0)
                new_sup[:,i] = (new_sup[:,i] - min(new_sup[:,i])) / (max(new_sup[:,i]) - min(new_sup[:,i])) 
                print(new_sup[:,i])
                

                # If data_model_year > start_year, backpropagate data by appropriate growth amount to start at zero electrification at start_year
                if data_model_year > start_year and data_model_year in x:
                    # Find growth amount at model year
                    model_year_idx = list(x).index(data_model_year)
                    model_year_supply_growth = new_sup[model_year_idx]
                    # Adjust what appliance initial consumption is by the growth at model year
                    initial_value /= model_year_supply_growth

                # Get new supply
                new_sup[:,i] = new_sup[:,i] * initial_value

            # Plot sigmoid functions
            plt.plot(x, new_sup[:,0]/1e9, color='tab:blue', label = 'Space heater')
            plt.axvline(x=X0[0],ls=':', color='tab:blue', label='Peak adoption year - space heater')

            plt.plot(x, new_sup[:,1]/1e9, color='tab:orange', label = 'Water heater')
            plt.axvline(x=X0[1], ls=':', color='tab:orange', label='Peak adoption year - water heater')

            plt.plot(x, new_sup[:,2]/1e9, color='tab:red', label = 'Cooling')
            plt.axvline(x=X0[2], ls=':', color='tab:red', label='Peak adoption year - cooling')

            plt.plot(x, new_sup[:,3]/1e9, color='tab:green', label = 'Interior equipment')
            plt.axvline(x=X0[3], ls=':', color='tab:green', label='Peak adoption year - interior equip.')

            # plt.axvline(x=X0[0], color='b', ls=':', label='Peak Adoption Year')
            plt.ylabel('New Supply (billion kWh)')
            plt.xlabel('year')
            plt.title(f'{state} Sigmoid Adoption Rate for End-Uses Electrification \n Start Year: {start_year}, Target Year: {target_year}')
            plt.legend(loc=2, prop={'size': 6})
            plt.grid()
            plt.show();
# Out:
# CA
# [2018 2019 2020 2021 2022 2023 2024 2025 2026 2027 2028 2029 2030 2031
#  2032 2033 2034 2035 2036 2037 2038 2039 2040 2041 2042 2043 2044 2045]
# [0.         0.00160236 0.00423303 0.00854016 0.01556066 0.02692105
#  0.04508966 0.07360825 0.11708453 0.18049898 0.26727742 0.37620622
#  0.49903716 0.62186811 0.73079691 0.81757535 0.8809898  0.92446608
#  0.95298467 0.97115327 0.98251367 0.98953417 0.9938413  0.99647197
#  0.99807433 0.99904872 0.99964064 1.        ]
# [0.         0.00160236 0.00423303 0.00854016 0.01556066 0.02692105
#  0.04508966 0.07360825 0.11708453 0.18049898 0.26727742 0.37620622
#  0.49903716 0.62186811 0.73079691 0.81757535 0.8809898  0.92446608
#  0.95298467 0.97115327 0.98251367 0.98953417 0.9938413  0.99647197
#  0.99807433 0.99904872 0.99964064 1.        ]
# [0.         0.00160236 0.00423303 0.00854016 0.01556066 0.02692105
#  0.04508966 0.07360825 0.11708453 0.18049898 0.26727742 0.37620622
#  0.49903716 0.62186811 0.73079691 0.81757535 0.8809898  0.92446608
#  0.95298467 0.97115327 0.98251367 0.98953417 0.9938413  0.99647197
#  0.99807433 0.99904872 0.99964064 1.        ]
# [0.         0.00160236 0.00423303 0.00854016 0.01556066 0.02692105
#  0.04508966 0.07360825 0.11708453 0.18049898 0.26727742 0.37620622
#  0.49903716 0.62186811 0.73079691 0.81757535 0.8809898  0.92446608
#  0.95298467 0.97115327 0.98251367 0.98953417 0.9938413  0.99647197
#  0.99807433 0.99904872 0.99964064 1.        ]
# NY
# [2020 2021 2022 2023 2024 2025 2026 2027 2028 2029 2030 2031 2032 2033
#  2034 2035 2036 2037 2038 2039 2040]
# [0.         0.00435235 0.01144658 0.02292626 0.04128566 0.07010372
#  0.11403653 0.17811689 0.26580658 0.37587923 0.5        0.62412077
#  0.73419342 0.82188311 0.88596347 0.92989628 0.95871434 0.97707374
#  0.98855342 0.99564765 1.        ]
# [0.         0.00435235 0.01144658 0.02292626 0.04128566 0.07010372
#  0.11403653 0.17811689 0.26580658 0.37587923 0.5        0.62412077
#  0.73419342 0.82188311 0.88596347 0.92989628 0.95871434 0.97707374
#  0.98855342 0.99564765 1.        ]
# [0.         0.00435235 0.01144658 0.02292626 0.04128566 0.07010372
#  0.11403653 0.17811689 0.26580658 0.37587923 0.5        0.62412077
#  0.73419342 0.82188311 0.88596347 0.92989628 0.95871434 0.97707374
#  0.98855342 0.99564765 1.        ]
# [0.         0.00435235 0.01144658 0.02292626 0.04128566 0.07010372
#  0.11403653 0.17811689 0.26580658 0.37587923 0.5        0.62412077
#  0.73419342 0.82188311 0.88596347 0.92989628 0.95871434 0.97707374
#  0.98855342 0.99564765 1.        ]
# TX
# [2025 2026 2027 2028 2029 2030 2031 2032 2033 2034 2035 2036 2037 2038
#  2039 2040 2041 2042 2043 2044 2045 2046 2047 2048 2049 2050]
# [0.         0.00263584 0.00695143 0.01398574 0.02536846 0.04357278
#  0.07214742 0.11570915 0.17924826 0.26619726 0.37534017 0.49841255
#  0.62148493 0.73062784 0.81757684 0.88111595 0.92467768 0.95325232
#  0.97145664 0.98283936 0.98987367 0.99418926 0.9968251  0.99843061
#  0.99940691 1.        ]
# [0.         0.00263584 0.00695143 0.01398574 0.02536846 0.04357278
#  0.07214742 0.11570915 0.17924826 0.26619726 0.37534017 0.49841255
#  0.62148493 0.73062784 0.81757684 0.88111595 0.92467768 0.95325232
#  0.97145664 0.98283936 0.98987367 0.99418926 0.9968251  0.99843061
#  0.99940691 1.        ]
# [0.         0.00263584 0.00695143 0.01398574 0.02536846 0.04357278
#  0.07214742 0.11570915 0.17924826 0.26619726 0.37534017 0.49841255
#  0.62148493 0.73062784 0.81757684 0.88111595 0.92467768 0.95325232
#  0.97145664 0.98283936 0.98987367 0.99418926 0.9968251  0.99843061
#  0.99940691 1.        ]
# [0.         0.00263584 0.00695143 0.01398574 0.02536846 0.04357278
#  0.07214742 0.11570915 0.17924826 0.26619726 0.37534017 0.49841255
#  0.62148493 0.73062784 0.81757684 0.88111595 0.92467768 0.95325232
#  0.97145664 0.98283936 0.98987367 0.99418926 0.9968251  0.99843061
#  0.99940691 1.        ]
# OH
# [2025 2026 2027 2028 2029 2030 2031 2032 2033 2034 2035 2036 2037 2038
#  2039 2040 2041 2042 2043 2044 2045 2046 2047 2048 2049 2050]
# [0.         0.00263584 0.00695143 0.01398574 0.02536846 0.04357278
#  0.07214742 0.11570915 0.17924826 0.26619726 0.37534017 0.49841255
#  0.62148493 0.73062784 0.81757684 0.88111595 0.92467768 0.95325232
#  0.97145664 0.98283936 0.98987367 0.99418926 0.9968251  0.99843061
#  0.99940691 1.        ]
# [0.         0.00263584 0.00695143 0.01398574 0.02536846 0.04357278
#  0.07214742 0.11570915 0.17924826 0.26619726 0.37534017 0.49841255
#  0.62148493 0.73062784 0.81757684 0.88111595 0.92467768 0.95325232
#  0.97145664 0.98283936 0.98987367 0.99418926 0.9968251  0.99843061
#  0.99940691 1.        ]
# [0.         0.00263584 0.00695143 0.01398574 0.02536846 0.04357278
#  0.07214742 0.11570915 0.17924826 0.26619726 0.37534017 0.49841255
#  0.62148493 0.73062784 0.81757684 0.88111595 0.92467768 0.95325232
#  0.97145664 0.98283936 0.98987367 0.99418926 0.9968251  0.99843061
#  0.99940691 1.        ]
# [0.         0.00263584 0.00695143 0.01398574 0.02536846 0.04357278
#  0.07214742 0.11570915 0.17924826 0.26619726 0.37534017 0.49841255
#  0.62148493 0.73062784 0.81757684 0.88111595 0.92467768 0.95325232
#  0.97145664 0.98283936 0.98987367 0.99418926 0.9968251  0.99843061
#  0.99940691 1.        ]
# NV
# [2025 2026 2027 2028 2029 2030 2031 2032 2033 2034 2035 2036 2037 2038
#  2039 2040 2041 2042 2043 2044 2045 2046 2047 2048 2049 2050]
# [0.         0.00263584 0.00695143 0.01398574 0.02536846 0.04357278
#  0.07214742 0.11570915 0.17924826 0.26619726 0.37534017 0.49841255
#  0.62148493 0.73062784 0.81757684 0.88111595 0.92467768 0.95325232
#  0.97145664 0.98283936 0.98987367 0.99418926 0.9968251  0.99843061
#  0.99940691 1.        ]
# [0.         0.00263584 0.00695143 0.01398574 0.02536846 0.04357278
#  0.07214742 0.11570915 0.17924826 0.26619726 0.37534017 0.49841255
#  0.62148493 0.73062784 0.81757684 0.88111595 0.92467768 0.95325232
#  0.97145664 0.98283936 0.98987367 0.99418926 0.9968251  0.99843061
#  0.99940691 1.        ]
# [0.         0.00263584 0.00695143 0.01398574 0.02536846 0.04357278
#  0.07214742 0.11570915 0.17924826 0.26619726 0.37534017 0.49841255
#  0.62148493 0.73062784 0.81757684 0.88111595 0.92467768 0.95325232
#  0.97145664 0.98283936 0.98987367 0.99418926 0.9968251  0.99843061
#  0.99940691 1.        ]
# [0.         0.00263584 0.00695143 0.01398574 0.02536846 0.04357278
#  0.07214742 0.11570915 0.17924826 0.26619726 0.37534017 0.49841255
#  0.62148493 0.73062784 0.81757684 0.88111595 0.92467768 0.95325232
#  0.97145664 0.98283936 0.98987367 0.99418926 0.9968251  0.99843061
#  0.99940691 1.        ]

# %%
for study_year in year_range:
    str_study_year = str(study_year)
    # create dict for all years
    results_comm[str_study_year] = {}

# %%
for study_year in year_range:
    print(study_year)
    str_study_year = str(study_year)
    
    for state in com_states:
        print(state)
        state_study_year = study_year
        results_comm[str_study_year][state] = {}
        
        # Set params for each state
        # Start year of electrification adoption
        start_year = state_start_year[state]
        # Target year
        target_year = state_target_year[state]
        # Peak adoption year per end use
        heater_year, water_year, cooling_year, ie_year = state_heater_year[state], state_water_year[state], state_cooling_year[state], state_ie_year[state]
        # Adoption rate per end use
        heater_AR, water_AR, cooling_AR, ie_AR = state_heater_AR[state], state_water_AR[state], state_cooling_AR[state], state_ie_AR[state]

        ########## Set Study Year #############
        x = np.arange(start_year, target_year + 1, 1)
        
        if state_study_year > target_year:
            # Assumed fully electrified
            state_study_year = target_year
            year_idx = list(x).index(target_year)
            
        if state_study_year in list(x):
            year_idx = list(x).index(state_study_year)  ##### why idx here only?
        elif state_study_year < list(x)[0]:
            # Electrification has not started yet
            # Assume state is same as start year
            state_study_year = list(x)[0]
            year_idx = 0
            
        if str(state_study_year) != str_study_year:
            results_comm[str(state_study_year)][state] = {}
        #######################################

        aggregation = "avg" # "avg" or "peak_day"
        month_start = 1
        month_end = 12
        day_type = None
        timezone = states_tz[state]
        

        for btype in BUILDING_TYPES:
            try:
                df = data[f"{state}_{btype}"]
            except KeyError:
                if state=="RI" or state=="VT" or state=="DC":
                    continue
                else:
                    raise

            comstock_heating = df[['Other Fuel Heating', 'Natural Gas Heating']].sum(axis=1)
            comstock_water_heating = df[['Other Fuel Water Heating', 'Natural Gas Water Heating']].sum(axis=1)
            comstock_cooling = df[['Other Fuel Cooling', 'Natural Gas Cooling']].sum(axis=1)
            comstock_ie = df[['Other Fuel Interior Equipment', 'Natural Gas Interior Equipment']].sum(axis=1)

            appliance = [comstock_heating, comstock_water_heating, comstock_cooling, comstock_ie]

            X0 = [heater_year, water_year, cooling_year, ie_year]
            K = [heater_AR, water_AR, cooling_AR, ie_AR]


            # Applying arithmetic or geometric growth rate to achieve electrification
            
            if plot_sigmoids:    
                # Generate x values
                x = np.linspace(start_year, target_year, 100)
                new_sup = np.zeros((len(x),len(appliance)))
                for i in range(len(appliance)):
                    # Initial and target value
                    initial_value = appliance[i].sum()

                    # Calculate parameters
                    x0 = X0[i]
                    k = K[i]/100  # adjust this to suit your needs

                    
                    new_sup[:,i] = sigmoid(x, 1, k, x0)
                    new_sup[:,i] = (new_sup[:,i] - min(new_sup[:,i])) / (max(new_sup[:,i]) - min(new_sup[:,i])) 
                    
                    # If data_model_year > start_year, backpropagate data by appropriate growth amount to start at zero electrification at start_year
                    if data_model_year > start_year and data_model_year in x:
                        # Find growth amount at model year
                        model_year_idx = list(x).index(data_model_year)
                        model_year_supply_growth = new_sup[model_year_idx]
                        # Adjust what appliance initial consumption is by the growth at model year
                        initial_value /= model_year_supply_growth

                    # Get new supply
                    new_sup[:,i] = new_sup[:,i] * initial_value

                # Plot sigmoid functions
                plt.plot(x, new_sup[:,0]/1e9, color='tab:blue', label = 'Space heater')
                plt.axvline(x=X0[0],ls=':', color='tab:blue', label='Peak adoption year - space heater')

                plt.plot(x, new_sup[:,1]/1e9, color='tab:orange', label = 'Water heater')
                plt.axvline(x=X0[1], ls=':', color='tab:orange', label='Peak adoption year - water heater')

                plt.plot(x, new_sup[:,2]/1e9, color='tab:red', label = 'Cooling')
                plt.axvline(x=X0[2], ls=':', color='tab:red', label='Peak adoption year - cooling')

                plt.plot(x, new_sup[:,3]/1e9, color='tab:green', label = 'Interior equipment')
                plt.axvline(x=X0[3], ls=':', color='tab:green', label='Peak adoption year - interior equip.')

                # plt.axvline(x=X0[0], color='b', ls=':', label='Peak Adoption Year')
                plt.ylabel('New Supply (billion kWh)')
                plt.xlabel('year')
                plt.title(f'{state} Sigmoid Adoption Rate for End-Uses Electrification \n Start Year: {start_year}, Target Year: {target_year}')
                plt.legend(loc=2, prop={'size': 6})
                plt.grid()
                plt.show();
                
        
            # Calculating the new supply for a given study year
            new_sup_sum = []

            for i, ap in enumerate(appliance):
                # Get new supply for all years 
                new_sup = sigmoid(x, 1, K[i]/100, X0[i])
                # Normalize sigmoid from 0 to 1
                new_sup = (new_sup - min(new_sup)) / (max(new_sup) - min(new_sup))
                
                # If start_year < data_model_year, assume the fuel consumption has not changed between data model year and start year, ie as if start_year = data_model_year
                if data_model_year <= start_year:
                    # Do nothing 
                    pass
                
                # If data_model_year > start_year, backpropagate data by appropriate growth amount to start at zero electrification at start_year
                if data_model_year > start_year and data_model_year in x:
                    # Find growth amount at model year
                    model_year_idx = list(x).index(data_model_year)
                    model_year_supply_growth = new_sup[model_year_idx]
                    # Adjust what appliance initial consumption is by the growth at model year
                    print(f"growth {model_year_supply_growth}, ap 2018 {ap[0]}, new ap init {ap[0]/model_year_supply_growth}")
                    ap /= model_year_supply_growth
               
                elif data_model_year > target_year: # not in range of years, ie model data is fully electrified 
                    raise("Not Implemented.")
                
                
                # For a given study year, retrieve the corresponding index
                new_sup = new_sup[year_idx] * ap
                new_sup_sum.append(new_sup.values)

            # Sum up the value for all appliances
            new_supply = np.asarray(new_sup_sum).transpose().sum(axis=1) 

            df['New Supply'] = new_supply
            df['New Electricity Total'] = new_supply  + df["Electricity Total"]
                

            # Aggregation of loadshape per state 
            df_agg = Timeseries.timeseries_aggregate(df, aggregation, month_start, month_end, day_type)

            # Time zone adjusting
            if timezone != 'EST':
                if timezone == 'CST':
                    shift = -1 # hrs
                elif timezone == 'MST':
                    shift = -2 # hrs
                elif timezone == 'PST':
                    shift = -3 # hrs
                df_old_values = df_agg[:-shift]
                df_agg = df_agg.shift(periods=shift)
                df_agg[shift:] = df_old_values.values

            df_agg['hour'] = pd.date_range("00:00", "23:45", freq="1H").hour
            # df_agg['minute'] = pd.date_range("00:00", "23:45", freq="1").minute
            df_agg["Load Growth"] = (df_agg["New Supply"]/df_agg["Electricity Total"]).values
            
            
             # Save total new supply added
            df_agg['Total Energy Added'] = df['New Supply'].values.sum()

            results_comm[str(state_study_year)][state][btype] = df_agg 
            
            if str(state_study_year) != str_study_year:
                results_comm[str_study_year][state][btype] = df_agg
# Out:
# 2023
# NY
# CA
# IL
# OH
# MI
# TX
# PA
# MA
# FL
# AL
# AR
# AZ
# CO
# CT
# DC
# DE
# GA
# IA
# ID
# IN
# KS
# KY
# LA
# MD
# ME
# MN
# MO
# MS
# MT
# NC
# ND
# NE
# NH
# NJ
# NM
# NV
# OK
# OR
# RI
# SC
# SD
# TN
# UT
# VA
# VT
# WA
# WI
# WV
# WY
# 2024
# NY
# CA
# IL
# OH
# MI
# TX
# PA
# MA
# FL
# AL
# AR
# AZ
# CO
# CT
# DC
# DE
# GA
# IA
# ID
# IN
# KS
# KY
# LA
# MD
# ME
# MN
# MO
# MS
# MT
# NC
# ND
# NE
# NH
# NJ
# NM
# NV
# OK
# OR
# RI
# SC
# SD
# TN
# UT
# VA
# VT
# WA
# WI
# WV
# WY
# 2025
# NY
# CA
# IL
# OH
# MI
# TX
# PA
# MA
# FL
# AL
# AR
# AZ
# CO
# CT
# DC
# DE
# GA
# IA
# ID
# IN
# KS
# KY
# LA
# MD
# ME
# MN
# MO
# MS
# MT
# NC
# ND
# NE
# NH
# NJ
# NM
# NV
# OK
# OR
# RI
# SC
# SD
# TN
# UT
# VA
# VT
# WA
# WI
# WV
# WY
# 2026
# NY
# CA
# IL
# OH
# MI
# TX
# PA
# MA
# FL
# AL
# AR
# AZ
# CO
# CT
# DC
# DE
# GA
# IA
# ID
# IN
# KS
# KY
# LA
# MD
# ME
# MN
# MO
# MS
# MT
# NC
# ND
# NE
# NH
# NJ
# NM
# NV
# OK
# OR
# RI
# SC
# SD
# TN
# UT
# VA
# VT
# WA
# WI
# WV
# WY
# 2027
# NY
# CA
# IL
# OH
# MI
# TX
# PA
# MA
# FL
# AL
# AR
# AZ
# CO
# CT
# DC
# DE
# GA
# IA
# ID
# IN
# KS
# KY
# LA
# MD
# ME
# MN
# MO
# MS
# MT
# NC
# ND
# NE
# NH
# NJ
# NM
# NV
# OK
# OR
# RI
# SC
# SD
# TN
# UT
# VA
# VT
# WA
# WI
# WV
# WY
# 2028
# NY
# CA
# IL
# OH
# MI
# TX
# PA
# MA
# FL
# AL
# AR
# AZ
# CO
# CT
# DC
# DE
# GA
# IA
# ID
# IN
# KS
# KY
# LA
# MD
# ME
# MN
# MO
# MS
# MT
# NC
# ND
# NE
# NH
# NJ
# NM
# NV
# OK
# OR
# RI
# SC
# SD
# TN
# UT
# VA
# VT
# WA
# WI
# WV
# WY
# 2029
# NY
# CA
# IL
# OH
# MI
# TX
# PA
# MA
# FL
# AL
# AR
# AZ
# CO
# CT
# DC
# DE
# GA
# IA
# ID
# IN
# KS
# KY
# LA
# MD
# ME
# MN
# MO
# MS
# MT
# NC
# ND
# NE
# NH
# NJ
# NM
# NV
# OK
# OR
# RI
# SC
# SD
# TN
# UT
# VA
# VT
# WA
# WI
# WV
# WY
# 2030
# NY
# CA
# IL
# OH
# MI
# TX
# PA
# MA
# FL
# AL
# AR
# AZ
# CO
# CT
# DC
# DE
# GA
# IA
# ID
# IN
# KS
# KY
# LA
# MD
# ME
# MN
# MO
# MS
# MT
# NC
# ND
# NE
# NH
# NJ
# NM
# NV
# OK
# OR
# RI
# SC
# SD
# TN
# UT
# VA
# VT
# WA
# WI
# WV
# WY
# 2031
# NY
# CA
# IL
# OH
# MI
# TX
# PA
# MA
# FL
# AL
# AR
# AZ
# CO
# CT
# DC
# DE
# GA
# IA
# ID
# IN
# KS
# KY
# LA
# MD
# ME
# MN
# MO
# MS
# MT
# NC
# ND
# NE
# NH
# NJ
# NM
# NV
# OK
# OR
# RI
# SC
# SD
# TN
# UT
# VA
# VT
# WA
# WI
# WV
# WY
# 2032
# NY
# CA
# IL
# OH
# MI
# TX
# PA
# MA
# FL
# AL
# AR
# AZ
# CO
# CT
# DC
# DE
# GA
# IA
# ID
# IN
# KS
# KY
# LA
# MD
# ME
# MN
# MO
# MS
# MT
# NC
# ND
# NE
# NH
# NJ
# NM
# NV
# OK
# OR
# RI
# SC
# SD
# TN
# UT
# VA
# VT
# WA
# WI
# WV
# WY
# 2033
# NY
# CA
# IL
# OH
# MI
# TX
# PA
# MA
# FL
# AL
# AR
# AZ
# CO
# CT
# DC
# DE
# GA
# IA
# ID
# IN
# KS
# KY
# LA
# MD
# ME
# MN
# MO
# MS
# MT
# NC
# ND
# NE
# NH
# NJ
# NM
# NV
# OK
# OR
# RI
# SC
# SD
# TN
# UT
# VA
# VT
# WA
# WI
# WV
# WY
# 2034
# NY
# CA
# IL
# OH
# MI
# TX
# PA
# MA
# FL
# AL
# AR
# AZ
# CO
# CT
# DC
# DE
# GA
# IA
# ID
# IN
# KS
# KY
# LA
# MD
# ME
# MN
# MO
# MS
# MT
# NC
# ND
# NE
# NH
# NJ
# NM
# NV
# OK
# OR
# RI
# SC
# SD
# TN
# UT
# VA
# VT
# WA
# WI
# WV
# WY
# 2035
# NY
# CA
# IL
# OH
# MI
# TX
# PA
# MA
# FL
# AL
# AR
# AZ
# CO
# CT
# DC
# DE
# GA
# IA
# ID
# IN
# KS
# KY
# LA
# MD
# ME
# MN
# MO
# MS
# MT
# NC
# ND
# NE
# NH
# NJ
# NM
# NV
# OK
# OR
# RI
# SC
# SD
# TN
# UT
# VA
# VT
# WA
# WI
# WV
# WY
# 2036
# NY
# CA
# IL
# OH
# MI
# TX
# PA
# MA
# FL
# AL
# AR
# AZ
# CO
# CT
# DC
# DE
# GA
# IA
# ID
# IN
# KS
# KY
# LA
# MD
# ME
# MN
# MO
# MS
# MT
# NC
# ND
# NE
# NH
# NJ
# NM
# NV
# OK
# OR
# RI
# SC
# SD
# TN
# UT
# VA
# VT
# WA
# WI
# WV
# WY
# 2037
# NY
# CA
# IL
# OH
# MI
# TX
# PA
# MA
# FL
# AL
# AR
# AZ
# CO
# CT
# DC
# DE
# GA
# IA
# ID
# IN
# KS
# KY
# LA
# MD
# ME
# MN
# MO
# MS
# MT
# NC
# ND
# NE
# NH
# NJ
# NM
# NV
# OK
# OR
# RI
# SC
# SD
# TN
# UT
# VA
# VT
# WA
# WI
# WV
# WY
# 2038
# NY
# CA
# IL
# OH
# MI
# TX
# PA
# MA
# FL
# AL
# AR
# AZ
# CO
# CT
# DC
# DE
# GA
# IA
# ID
# IN
# KS
# KY
# LA
# MD
# ME
# MN
# MO
# MS
# MT
# NC
# ND
# NE
# NH
# NJ
# NM
# NV
# OK
# OR
# RI
# SC
# SD
# TN
# UT
# VA
# VT
# WA
# WI
# WV
# WY
# 2039
# NY
# CA
# IL
# OH
# MI
# TX
# PA
# MA
# FL
# AL
# AR
# AZ
# CO
# CT
# DC
# DE
# GA
# IA
# ID
# IN
# KS
# KY
# LA
# MD
# ME
# MN
# MO
# MS
# MT
# NC
# ND
# NE
# NH
# NJ
# NM
# NV
# OK
# OR
# RI
# SC
# SD
# TN
# UT
# VA
# VT
# WA
# WI
# WV
# WY
# 2040
# NY
# CA
# IL
# OH
# MI
# TX
# PA
# MA
# FL
# AL
# AR
# AZ
# CO
# CT
# DC
# DE
# GA
# IA
# ID
# IN
# KS
# KY
# LA
# MD
# ME
# MN
# MO
# MS
# MT
# NC
# ND
# NE
# NH
# NJ
# NM
# NV
# OK
# OR
# RI
# SC
# SD
# TN
# UT
# VA
# VT
# WA
# WI
# WV
# WY
# 2041
# NY
# CA
# IL
# OH
# MI
# TX
# PA
# MA
# FL
# AL
# AR
# AZ
# CO
# CT
# DC
# DE
# GA
# IA
# ID
# IN
# KS
# KY
# LA
# MD
# ME
# MN
# MO
# MS
# MT
# NC
# ND
# NE
# NH
# NJ
# NM
# NV
# OK
# OR
# RI
# SC
# SD
# TN
# UT
# VA
# VT
# WA
# WI
# WV
# WY
# 2042
# NY
# CA
# IL
# OH
# MI
# TX
# PA
# MA
# FL
# AL
# AR
# AZ
# CO
# CT
# DC
# DE
# GA
# IA
# ID
# IN
# KS
# KY
# LA
# MD
# ME
# MN
# MO
# MS
# MT
# NC
# ND
# NE
# NH
# NJ
# NM
# NV
# OK
# OR
# RI
# SC
# SD
# TN
# UT
# VA
# VT
# WA
# WI
# WV
# WY
# 2043
# NY
# CA
# IL
# OH
# MI
# TX
# PA
# MA
# FL
# AL
# AR
# AZ
# CO
# CT
# DC
# DE
# GA
# IA
# ID
# IN
# KS
# KY
# LA
# MD
# ME
# MN
# MO
# MS
# MT
# NC
# ND
# NE
# NH
# NJ
# NM
# NV
# OK
# OR
# RI
# SC
# SD
# TN
# UT
# VA
# VT
# WA
# WI
# WV
# WY
# 2044
# NY
# CA
# IL
# OH
# MI
# TX
# PA
# MA
# FL
# AL
# AR
# AZ
# CO
# CT
# DC
# DE
# GA
# IA
# ID
# IN
# KS
# KY
# LA
# MD
# ME
# MN
# MO
# MS
# MT
# NC
# ND
# NE
# NH
# NJ
# NM
# NV
# OK
# OR
# RI
# SC
# SD
# TN
# UT
# VA
# VT
# WA
# WI
# WV
# WY
# 2045
# NY
# CA
# IL
# OH
# MI
# TX
# PA
# MA
# FL
# AL
# AR
# AZ
# CO
# CT
# DC
# DE
# GA
# IA
# ID
# IN
# KS
# KY
# LA
# MD
# ME
# MN
# MO
# MS
# MT
# NC
# ND
# NE
# NH
# NJ
# NM
# NV
# OK
# OR
# RI
# SC
# SD
# TN
# UT
# VA
# VT
# WA
# WI
# WV
# WY
# 2046
# NY
# CA
# IL
# OH
# MI
# TX
# PA
# MA
# FL
# AL
# AR
# AZ
# CO
# CT
# DC
# DE
# GA
# IA
# ID
# IN
# KS
# KY
# LA
# MD
# ME
# MN
# MO
# MS
# MT
# NC
# ND
# NE
# NH
# NJ
# NM
# NV
# OK
# OR
# RI
# SC
# SD
# TN
# UT
# VA
# VT
# WA
# WI
# WV
# WY
# 2047
# NY
# CA
# IL
# OH
# MI
# TX
# PA
# MA
# FL
# AL
# AR
# AZ
# CO
# CT
# DC
# DE
# GA
# IA
# ID
# IN
# KS
# KY
# LA
# MD
# ME
# MN
# MO
# MS
# MT
# NC
# ND
# NE
# NH
# NJ
# NM
# NV
# OK
# OR
# RI
# SC
# SD
# TN
# UT
# VA
# VT
# WA
# WI
# WV
# WY
# 2048
# NY
# CA
# IL
# OH
# MI
# TX
# PA
# MA
# FL
# AL
# AR
# AZ
# CO
# CT
# DC
# DE
# GA
# IA
# ID
# IN
# KS
# KY
# LA
# MD
# ME
# MN
# MO
# MS
# MT
# NC
# ND
# NE
# NH
# NJ
# NM
# NV
# OK
# OR
# RI
# SC
# SD
# TN
# UT
# VA
# VT
# WA
# WI
# WV
# WY
# 2049
# NY
# CA
# IL
# OH
# MI
# TX
# PA
# MA
# FL
# AL
# AR
# AZ
# CO
# CT
# DC
# DE
# GA
# IA
# ID
# IN
# KS
# KY
# LA
# MD
# ME
# MN
# MO
# MS
# MT
# NC
# ND
# NE
# NH
# NJ
# NM
# NV
# OK
# OR
# RI
# SC
# SD
# TN
# UT
# VA
# VT
# WA
# WI
# WV
# WY
# 2050
# NY
# CA
# IL
# OH
# MI
# TX
# PA
# MA
# FL
# AL
# AR
# AZ
# CO
# CT
# DC
# DE
# GA
# IA
# ID
# IN
# KS
# KY
# LA
# MD
# ME
# MN
# MO
# MS
# MT
# NC
# ND
# NE
# NH
# NJ
# NM
# NV
# OK
# OR
# RI
# SC
# SD
# TN
# UT
# VA
# VT
# WA
# WI
# WV
# WY

# %% [markdown]
# ## Get peaks and peak times of the sum of the building types for each state

# %%
for study_year in year_range:
    print(study_year)
    str_study_year = str(study_year)
    
    for state in com_states:
        print(state)
        
        # Sums over state btype
        state_elec_total = pd.Series([0]*24, name="State Electricity Total")
        state_new_elec_total = pd.Series([0]*24, name="State New Electricity Total")
        state_new_supply = pd.Series([0]*24, name="State New Supply")
        state_total_energy_added = pd.Series([0]*24, name="State Total Energy Added")

        
        for btype in BUILDING_TYPES:
            
            try:
                state_elec_total += results_comm[str_study_year][state][btype]["Electricity Total"]     
                state_new_elec_total += results_comm[str_study_year][state][btype]["New Electricity Total"] 
                state_new_supply += results_comm[str_study_year][state][btype]["New Supply"]
                state_total_energy_added += results_comm[str_study_year][state][btype]["Total Energy Added"]
            except KeyError:
                if state=="RI" or state=="VT" or state=="DC":
                    continue
                else:
                    raise
        
        
        # Df of sums over state
        state_sums_df = pd.concat([df_agg["hour"], state_elec_total, state_new_elec_total, state_new_supply, state_total_energy_added], axis=1)
        state_sums_df["State Load Growth"] = (state_sums_df["State New Supply"]/state_sums_df["State Electricity Total"])

        results_comm[str_study_year][state]["Sums"] = state_sums_df
        
        # Loadshape analysis to get peak times 
        peak, peak_time, new_peak, new_peak_time, load_growth, supply_peak, supply_peak_time = loadshape_analysis(state_sums_df)        
        results_comm[str_study_year][state]["Total Energy Supply Added from Current Energy Consumption"] = state_sums_df["State Total Energy Added"][0]/1e9
        results_comm[str_study_year][state]["Total Energy Supply Added from Current Energy Consumption - units"] = "TWh"
        results_comm[str_study_year][state]["Current Peak"]  = np.round(peak[0],0)
        results_comm[str_study_year][state]["Current Peak - units"] = "MW"
        results_comm[str_study_year][state]["Current Peak - time"] = peak_time
        results_comm[str_study_year][state]["New Peak"]  = np.round(new_peak[0],0)
        results_comm[str_study_year][state]["New Peak - units"] = "MW"
        results_comm[str_study_year][state]["New Peak - time"] = new_peak_time
        results_comm[str_study_year][state]["New Supply"]  = np.round(supply_peak[0],0)
        results_comm[str_study_year][state]["New Supply - units"] = "MW"
        results_comm[str_study_year][state]["New Supply - time"] = supply_peak_time
        results_comm[str_study_year][state]["Load Growth"]  = np.round(load_growth,2)
        results_comm[str_study_year][state]["Load Growth - units"] = "%"
        results_comm[str_study_year][state]["Load Growth - time"] = new_peak_time

        
#         # Plot sum over btype for each state
#         t = state_sums_df["hour"]

#         # Plotting elec
#         plt.plot(t, state_sums_df['State Electricity Total']/1e3 *(60/15), label = 'Current Loadshape')
#         plt.plot(t, state_sums_df['State New Electricity Total']/1e3 *(60/15), label = 'Loadshape with Electrification')
#         #plt.ylim(bottom=0)
#         plt.xlabel('Hour (hr)')
#         plt.ylabel('Power demand (MW)')
#         plt.xticks([0,6,12,18,24])
#         plt.title(str(state) + ' ' + ' Loadshape with Electrification - ' + str(aggregation) + ' over year ' + str(study_year))
#         plt.grid(alpha=0.3)
#         plt.legend()
#         plt.show()

        print(f"Total Energy supply added from current energy consumption = {np.round(state_sums_df['State Total Energy Added'][0]/1e9, 1)}  TWh") 
        print(f"Current Peak {np.round(peak[0],0)} MW, time: {peak_time}")
        print(f"New Peak     {np.round(new_peak[0],0)} MW, time: {new_peak_time}")
        print(f"New Supply   {np.round(supply_peak[0],0)} MW, time: {supply_peak_time}")
        print(f"Load Growth  {np.round(load_growth,2)} %, time: {new_peak_time}")
# Out:
# 2023
# NY
# Total Energy supply added from current energy consumption = 0.6  TWh
# Current Peak 8181.0 MW, time: 11:00
# New Peak     8274.0 MW, time: 11:00
# New Supply   97.0 MW, time: 10:00
# Load Growth  1.15 %, time: 11:00
# CA
# Total Energy supply added from current energy consumption = 1.2  TWh
# Current Peak 17267.0 MW, time: 12:00
# New Peak     17439.0 MW, time: 12:00
# New Supply   197.0 MW, time: 9:00
# Load Growth  1.0 %, time: 12:00
# IL
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 5403.0 MW, time: 12:00
# New Peak     5403.0 MW, time: 12:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 12:00
# OH
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 5586.0 MW, time: 11:00
# New Peak     5586.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# MI
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 3529.0 MW, time: 12:00
# New Peak     3529.0 MW, time: 12:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 12:00
# TX
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 15412.0 MW, time: 12:00
# New Peak     15412.0 MW, time: 12:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 12:00
# PA
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 5709.0 MW, time: 11:00
# New Peak     5709.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# MA
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 3304.0 MW, time: 11:00
# New Peak     3304.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# FL
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 13360.0 MW, time: 12:00
# New Peak     13360.0 MW, time: 12:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 12:00
# AL
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 2171.0 MW, time: 12:00
# New Peak     2171.0 MW, time: 12:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 12:00
# AR
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 1508.0 MW, time: 12:00
# New Peak     1508.0 MW, time: 12:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 12:00
# AZ
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 3169.0 MW, time: 13:00
# New Peak     3169.0 MW, time: 13:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 13:00
# CO
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 2154.0 MW, time: 11:00
# New Peak     2154.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# CT
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 1463.0 MW, time: 11:00
# New Peak     1463.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# DC
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 673.0 MW, time: 10:00
# New Peak     673.0 MW, time: 10:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 10:00
# DE
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 342.0 MW, time: 12:00
# New Peak     342.0 MW, time: 12:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 12:00
# GA
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 4972.0 MW, time: 12:00
# New Peak     4972.0 MW, time: 12:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 12:00
# IA
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 1090.0 MW, time: 11:00
# New Peak     1090.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# ID
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 574.0 MW, time: 12:00
# New Peak     574.0 MW, time: 12:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 12:00
# IN
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 2791.0 MW, time: 12:00
# New Peak     2791.0 MW, time: 12:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 12:00
# KS
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 1380.0 MW, time: 12:00
# New Peak     1380.0 MW, time: 12:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 12:00
# KY
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 1615.0 MW, time: 11:00
# New Peak     1615.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# LA
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 2528.0 MW, time: 12:00
# New Peak     2528.0 MW, time: 12:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 12:00
# MD
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 2406.0 MW, time: 11:00
# New Peak     2406.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# ME
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 522.0 MW, time: 11:00
# New Peak     522.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# MN
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 2203.0 MW, time: 11:00
# New Peak     2203.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# MO
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 3087.0 MW, time: 11:00
# New Peak     3087.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# MS
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 1185.0 MW, time: 12:00
# New Peak     1185.0 MW, time: 12:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 12:00
# MT
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 274.0 MW, time: 11:00
# New Peak     274.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# NC
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 4416.0 MW, time: 12:00
# New Peak     4416.0 MW, time: 12:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 12:00
# ND
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 222.0 MW, time: 10:00
# New Peak     222.0 MW, time: 10:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 10:00
# NE
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 804.0 MW, time: 11:00
# New Peak     804.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# NH
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 485.0 MW, time: 11:00
# New Peak     485.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# NJ
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 4029.0 MW, time: 11:00
# New Peak     4029.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# NM
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 822.0 MW, time: 12:00
# New Peak     822.0 MW, time: 12:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 12:00
# NV
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 1521.0 MW, time: 12:00
# New Peak     1521.0 MW, time: 12:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 12:00
# OK
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 2009.0 MW, time: 12:00
# New Peak     2009.0 MW, time: 12:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 12:00
# OR
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 1282.0 MW, time: 12:00
# New Peak     1282.0 MW, time: 12:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 12:00
# RI
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 408.0 MW, time: 11:00
# New Peak     408.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# SC
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 2827.0 MW, time: 12:00
# New Peak     2827.0 MW, time: 12:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 12:00
# SD
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 259.0 MW, time: 11:00
# New Peak     259.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# TN
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 3393.0 MW, time: 11:00
# New Peak     3393.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# UT
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 1108.0 MW, time: 12:00
# New Peak     1108.0 MW, time: 12:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 12:00
# VA
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 3580.0 MW, time: 11:00
# New Peak     3580.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# VT
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 135.0 MW, time: 11:00
# New Peak     135.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# WA
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 2130.0 MW, time: 11:00
# New Peak     2130.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# WI
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 2333.0 MW, time: 11:00
# New Peak     2333.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# WV
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 868.0 MW, time: 12:00
# New Peak     868.0 MW, time: 12:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 12:00
# WY
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 150.0 MW, time: 12:00
# New Peak     150.0 MW, time: 12:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 12:00
# 2024
# NY
# Total Energy supply added from current energy consumption = 1.0  TWh
# Current Peak 8181.0 MW, time: 11:00
# New Peak     8338.0 MW, time: 11:00
# New Supply   162.0 MW, time: 10:00
# Load Growth  1.92 %, time: 11:00
# CA
# Total Energy supply added from current energy consumption = 1.9  TWh
# Current Peak 17267.0 MW, time: 12:00
# New Peak     17555.0 MW, time: 12:00
# New Supply   330.0 MW, time: 9:00
# Load Growth  1.67 %, time: 12:00
# IL
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 5403.0 MW, time: 12:00
# New Peak     5406.0 MW, time: 12:00
# New Supply   3.0 MW, time: 7:00
# Load Growth  0.05 %, time: 12:00
# OH
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 5586.0 MW, time: 11:00
# New Peak     5586.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# MI
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 3529.0 MW, time: 12:00
# New Peak     3531.0 MW, time: 12:00
# New Supply   2.0 MW, time: 7:00
# Load Growth  0.06 %, time: 12:00
# TX
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 15412.0 MW, time: 12:00
# New Peak     15412.0 MW, time: 12:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 12:00
# PA
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 5709.0 MW, time: 11:00
# New Peak     5709.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# MA
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 3304.0 MW, time: 11:00
# New Peak     3305.0 MW, time: 11:00
# New Supply   1.0 MW, time: 9:00
# Load Growth  0.03 %, time: 11:00
# FL
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 13360.0 MW, time: 12:00
# New Peak     13362.0 MW, time: 12:00
# New Supply   3.0 MW, time: 11:00
# Load Growth  0.02 %, time: 12:00
# AL
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 2171.0 MW, time: 12:00
# New Peak     2171.0 MW, time: 12:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 12:00
# AR
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 1508.0 MW, time: 12:00
# New Peak     1508.0 MW, time: 12:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 12:00
# AZ
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 3169.0 MW, time: 13:00
# New Peak     3169.0 MW, time: 13:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 13:00
# CO
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 2154.0 MW, time: 11:00
# New Peak     2154.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# CT
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 1463.0 MW, time: 11:00
# New Peak     1463.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# DC
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 673.0 MW, time: 10:00
# New Peak     673.0 MW, time: 10:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 10:00
# DE
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 342.0 MW, time: 12:00
# New Peak     342.0 MW, time: 12:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 12:00
# GA
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 4972.0 MW, time: 12:00
# New Peak     4972.0 MW, time: 12:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 12:00
# IA
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 1090.0 MW, time: 11:00
# New Peak     1090.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# ID
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 574.0 MW, time: 12:00
# New Peak     574.0 MW, time: 12:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 12:00
# IN
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 2791.0 MW, time: 12:00
# New Peak     2791.0 MW, time: 12:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 12:00
# KS
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 1380.0 MW, time: 12:00
# New Peak     1380.0 MW, time: 12:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 12:00
# KY
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 1615.0 MW, time: 11:00
# New Peak     1615.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# LA
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 2528.0 MW, time: 12:00
# New Peak     2528.0 MW, time: 12:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 12:00
# MD
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 2406.0 MW, time: 11:00
# New Peak     2406.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# ME
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 522.0 MW, time: 11:00
# New Peak     522.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# MN
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 2203.0 MW, time: 11:00
# New Peak     2203.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# MO
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 3087.0 MW, time: 11:00
# New Peak     3087.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# MS
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 1185.0 MW, time: 12:00
# New Peak     1185.0 MW, time: 12:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 12:00
# MT
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 274.0 MW, time: 11:00
# New Peak     274.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# NC
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 4416.0 MW, time: 12:00
# New Peak     4416.0 MW, time: 12:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 12:00
# ND
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 222.0 MW, time: 10:00
# New Peak     222.0 MW, time: 10:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 10:00
# NE
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 804.0 MW, time: 11:00
# New Peak     804.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# NH
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 485.0 MW, time: 11:00
# New Peak     485.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# NJ
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 4029.0 MW, time: 11:00
# New Peak     4029.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# NM
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 822.0 MW, time: 12:00
# New Peak     822.0 MW, time: 12:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 12:00
# NV
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 1521.0 MW, time: 12:00
# New Peak     1521.0 MW, time: 12:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 12:00
# OK
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 2009.0 MW, time: 12:00
# New Peak     2009.0 MW, time: 12:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 12:00
# OR
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 1282.0 MW, time: 12:00
# New Peak     1282.0 MW, time: 12:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 12:00
# RI
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 408.0 MW, time: 11:00
# New Peak     408.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# SC
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 2827.0 MW, time: 12:00
# New Peak     2827.0 MW, time: 12:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 12:00
# SD
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 259.0 MW, time: 11:00
# New Peak     259.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# TN
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 3393.0 MW, time: 11:00
# New Peak     3393.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# UT
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 1108.0 MW, time: 12:00
# New Peak     1108.0 MW, time: 12:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 12:00
# VA
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 3580.0 MW, time: 11:00
# New Peak     3580.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# VT
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 135.0 MW, time: 11:00
# New Peak     135.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# WA
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 2130.0 MW, time: 11:00
# New Peak     2130.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# WI
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 2333.0 MW, time: 11:00
# New Peak     2333.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# WV
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 868.0 MW, time: 12:00
# New Peak     868.0 MW, time: 12:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 12:00
# WY
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 150.0 MW, time: 12:00
# New Peak     150.0 MW, time: 12:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 12:00
# 2025
# NY
# Total Energy supply added from current energy consumption = 1.7  TWh
# Current Peak 8181.0 MW, time: 11:00
# New Peak     8437.0 MW, time: 11:00
# New Supply   264.0 MW, time: 10:00
# Load Growth  3.13 %, time: 11:00
# CA
# Total Energy supply added from current energy consumption = 3.2  TWh
# Current Peak 17267.0 MW, time: 12:00
# New Peak     17738.0 MW, time: 12:00
# New Supply   539.0 MW, time: 9:00
# Load Growth  2.73 %, time: 12:00
# IL
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 5403.0 MW, time: 12:00
# New Peak     5410.0 MW, time: 12:00
# New Supply   8.0 MW, time: 7:00
# Load Growth  0.12 %, time: 12:00
# OH
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 5586.0 MW, time: 11:00
# New Peak     5586.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# MI
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 3529.0 MW, time: 12:00
# New Peak     3534.0 MW, time: 12:00
# New Supply   6.0 MW, time: 7:00
# Load Growth  0.15 %, time: 12:00
# TX
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 15412.0 MW, time: 12:00
# New Peak     15412.0 MW, time: 12:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 12:00
# PA
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 5709.0 MW, time: 11:00
# New Peak     5709.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# MA
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 3304.0 MW, time: 11:00
# New Peak     3307.0 MW, time: 11:00
# New Supply   3.0 MW, time: 9:00
# Load Growth  0.09 %, time: 11:00
# FL
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 13360.0 MW, time: 12:00
# New Peak     13367.0 MW, time: 12:00
# New Supply   8.0 MW, time: 11:00
# Load Growth  0.05 %, time: 12:00
# AL
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 2171.0 MW, time: 12:00
# New Peak     2171.0 MW, time: 12:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 12:00
# AR
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 1508.0 MW, time: 12:00
# New Peak     1508.0 MW, time: 12:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 12:00
# AZ
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 3169.0 MW, time: 13:00
# New Peak     3169.0 MW, time: 13:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 13:00
# CO
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 2154.0 MW, time: 11:00
# New Peak     2154.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# CT
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 1463.0 MW, time: 11:00
# New Peak     1463.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# DC
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 673.0 MW, time: 10:00
# New Peak     673.0 MW, time: 10:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 10:00
# DE
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 342.0 MW, time: 12:00
# New Peak     342.0 MW, time: 12:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 12:00
# GA
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 4972.0 MW, time: 12:00
# New Peak     4972.0 MW, time: 12:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 12:00
# IA
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 1090.0 MW, time: 11:00
# New Peak     1090.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# ID
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 574.0 MW, time: 12:00
# New Peak     574.0 MW, time: 12:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 12:00
# IN
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 2791.0 MW, time: 12:00
# New Peak     2791.0 MW, time: 12:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 12:00
# KS
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 1380.0 MW, time: 12:00
# New Peak     1380.0 MW, time: 12:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 12:00
# KY
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 1615.0 MW, time: 11:00
# New Peak     1615.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# LA
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 2528.0 MW, time: 12:00
# New Peak     2528.0 MW, time: 12:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 12:00
# MD
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 2406.0 MW, time: 11:00
# New Peak     2406.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# ME
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 522.0 MW, time: 11:00
# New Peak     522.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# MN
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 2203.0 MW, time: 11:00
# New Peak     2203.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# MO
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 3087.0 MW, time: 11:00
# New Peak     3087.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# MS
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 1185.0 MW, time: 12:00
# New Peak     1185.0 MW, time: 12:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 12:00
# MT
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 274.0 MW, time: 11:00
# New Peak     274.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# NC
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 4416.0 MW, time: 12:00
# New Peak     4416.0 MW, time: 12:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 12:00
# ND
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 222.0 MW, time: 10:00
# New Peak     222.0 MW, time: 10:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 10:00
# NE
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 804.0 MW, time: 11:00
# New Peak     804.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# NH
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 485.0 MW, time: 11:00
# New Peak     485.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# NJ
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 4029.0 MW, time: 11:00
# New Peak     4029.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# NM
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 822.0 MW, time: 12:00
# New Peak     822.0 MW, time: 12:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 12:00
# NV
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 1521.0 MW, time: 12:00
# New Peak     1521.0 MW, time: 12:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 12:00
# OK
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 2009.0 MW, time: 12:00
# New Peak     2009.0 MW, time: 12:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 12:00
# OR
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 1282.0 MW, time: 12:00
# New Peak     1282.0 MW, time: 12:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 12:00
# RI
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 408.0 MW, time: 11:00
# New Peak     408.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# SC
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 2827.0 MW, time: 12:00
# New Peak     2827.0 MW, time: 12:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 12:00
# SD
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 259.0 MW, time: 11:00
# New Peak     259.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# TN
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 3393.0 MW, time: 11:00
# New Peak     3393.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# UT
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 1108.0 MW, time: 12:00
# New Peak     1108.0 MW, time: 12:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 12:00
# VA
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 3580.0 MW, time: 11:00
# New Peak     3580.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# VT
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 135.0 MW, time: 11:00
# New Peak     135.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# WA
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 2130.0 MW, time: 11:00
# New Peak     2130.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# WI
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 2333.0 MW, time: 11:00
# New Peak     2333.0 MW, time: 11:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 11:00
# WV
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 868.0 MW, time: 12:00
# New Peak     868.0 MW, time: 12:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 12:00
# WY
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 150.0 MW, time: 12:00
# New Peak     150.0 MW, time: 12:00
# New Supply   0.0 MW, time: 0:00
# Load Growth  0.0 %, time: 12:00
# 2026
# NY
# Total Energy supply added from current energy consumption = 2.7  TWh
# Current Peak 8181.0 MW, time: 11:00
# New Peak     8589.0 MW, time: 11:00
# New Supply   421.0 MW, time: 10:00
# Load Growth  4.99 %, time: 11:00
# CA
# Total Energy supply added from current energy consumption = 5.0  TWh
# Current Peak 17267.0 MW, time: 12:00
# New Peak     18017.0 MW, time: 12:00
# New Supply   857.0 MW, time: 9:00
# Load Growth  4.34 %, time: 12:00
# IL
# Total Energy supply added from current energy consumption = 0.1  TWh
# Current Peak 5403.0 MW, time: 12:00
# New Peak     5417.0 MW, time: 12:00
# New Supply   15.0 MW, time: 7:00
# Load Growth  0.25 %, time: 12:00
# OH
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 5586.0 MW, time: 11:00
# New Peak     5593.0 MW, time: 11:00
# New Supply   7.0 MW, time: 10:00
# Load Growth  0.13 %, time: 11:00
# MI
# Total Energy supply added from current energy consumption = 0.1  TWh
# Current Peak 3529.0 MW, time: 12:00
# New Peak     3540.0 MW, time: 12:00
# New Supply   13.0 MW, time: 7:00
# Load Growth  0.3 %, time: 12:00
# TX
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 15412.0 MW, time: 12:00
# New Peak     15420.0 MW, time: 12:00
# New Supply   9.0 MW, time: 10:00
# Load Growth  0.05 %, time: 12:00
# PA
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 5709.0 MW, time: 11:00
# New Peak     5714.0 MW, time: 11:00
# New Supply   6.0 MW, time: 10:00
# Load Growth  0.1 %, time: 11:00
# MA
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 3304.0 MW, time: 11:00
# New Peak     3310.0 MW, time: 11:00
# New Supply   6.0 MW, time: 9:00
# Load Growth  0.19 %, time: 11:00
# FL
# Total Energy supply added from current energy consumption = 0.1  TWh
# Current Peak 13360.0 MW, time: 12:00
# New Peak     13374.0 MW, time: 12:00
# New Supply   16.0 MW, time: 11:00
# Load Growth  0.11 %, time: 12:00
# AL
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 2171.0 MW, time: 12:00
# New Peak     2172.0 MW, time: 12:00
# New Supply   1.0 MW, time: 10:00
# Load Growth  0.06 %, time: 12:00
# AR
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 1508.0 MW, time: 12:00
# New Peak     1509.0 MW, time: 12:00
# New Supply   1.0 MW, time: 10:00
# Load Growth  0.07 %, time: 12:00
# AZ
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 3169.0 MW, time: 13:00
# New Peak     3171.0 MW, time: 13:00
# New Supply   2.0 MW, time: 10:00
# Load Growth  0.04 %, time: 13:00
# CO
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 2154.0 MW, time: 11:00
# New Peak     2156.0 MW, time: 11:00
# New Supply   3.0 MW, time: 7:00
# Load Growth  0.11 %, time: 11:00
# CT
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 1463.0 MW, time: 11:00
# New Peak     1464.0 MW, time: 11:00
# New Supply   2.0 MW, time: 10:00
# Load Growth  0.1 %, time: 11:00
# DC
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 673.0 MW, time: 10:00
# New Peak     673.0 MW, time: 10:00
# New Supply   0.0 MW, time: 10:00
# Load Growth  0.05 %, time: 10:00
# DE
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 342.0 MW, time: 12:00
# New Peak     342.0 MW, time: 12:00
# New Supply   0.0 MW, time: 10:00
# Load Growth  0.09 %, time: 12:00
# GA
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 4972.0 MW, time: 12:00
# New Peak     4975.0 MW, time: 12:00
# New Supply   3.0 MW, time: 10:00
# Load Growth  0.06 %, time: 12:00
# IA
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 1090.0 MW, time: 11:00
# New Peak     1092.0 MW, time: 11:00
# New Supply   2.0 MW, time: 9:00
# Load Growth  0.13 %, time: 11:00
# ID
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 574.0 MW, time: 12:00
# New Peak     575.0 MW, time: 12:00
# New Supply   1.0 MW, time: 9:00
# Load Growth  0.11 %, time: 12:00
# IN
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 2791.0 MW, time: 12:00
# New Peak     2794.0 MW, time: 12:00
# New Supply   3.0 MW, time: 10:00
# Load Growth  0.11 %, time: 12:00
# KS
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 1380.0 MW, time: 12:00
# New Peak     1381.0 MW, time: 12:00
# New Supply   1.0 MW, time: 9:00
# Load Growth  0.08 %, time: 12:00
# KY
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 1615.0 MW, time: 11:00
# New Peak     1616.0 MW, time: 11:00
# New Supply   2.0 MW, time: 9:00
# Load Growth  0.09 %, time: 11:00
# LA
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 2528.0 MW, time: 12:00
# New Peak     2530.0 MW, time: 12:00
# New Supply   2.0 MW, time: 10:00
# Load Growth  0.06 %, time: 12:00
# MD
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 2406.0 MW, time: 11:00
# New Peak     2408.0 MW, time: 11:00
# New Supply   2.0 MW, time: 10:00
# Load Growth  0.08 %, time: 11:00
# ME
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 522.0 MW, time: 11:00
# New Peak     523.0 MW, time: 11:00
# New Supply   1.0 MW, time: 10:00
# Load Growth  0.12 %, time: 11:00
# MN
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 2203.0 MW, time: 11:00
# New Peak     2206.0 MW, time: 11:00
# New Supply   4.0 MW, time: 9:00
# Load Growth  0.16 %, time: 11:00
# MO
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 3087.0 MW, time: 11:00
# New Peak     3090.0 MW, time: 11:00
# New Supply   3.0 MW, time: 10:00
# Load Growth  0.08 %, time: 11:00
# MS
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 1185.0 MW, time: 12:00
# New Peak     1186.0 MW, time: 12:00
# New Supply   1.0 MW, time: 10:00
# Load Growth  0.06 %, time: 12:00
# MT
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 274.0 MW, time: 11:00
# New Peak     275.0 MW, time: 11:00
# New Supply   1.0 MW, time: 9:00
# Load Growth  0.18 %, time: 11:00
# NC
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 4416.0 MW, time: 12:00
# New Peak     4419.0 MW, time: 12:00
# New Supply   3.0 MW, time: 10:00
# Load Growth  0.06 %, time: 12:00
# ND
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 222.0 MW, time: 10:00
# New Peak     222.0 MW, time: 10:00
# New Supply   0.0 MW, time: 10:00
# Load Growth  0.14 %, time: 10:00
# NE
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 804.0 MW, time: 11:00
# New Peak     805.0 MW, time: 11:00
# New Supply   1.0 MW, time: 9:00
# Load Growth  0.13 %, time: 11:00
# NH
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 485.0 MW, time: 11:00
# New Peak     486.0 MW, time: 11:00
# New Supply   1.0 MW, time: 10:00
# Load Growth  0.12 %, time: 11:00
# NJ
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 4029.0 MW, time: 11:00
# New Peak     4033.0 MW, time: 11:00
# New Supply   4.0 MW, time: 10:00
# Load Growth  0.11 %, time: 11:00
# NM
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 822.0 MW, time: 12:00
# New Peak     823.0 MW, time: 12:00
# New Supply   1.0 MW, time: 9:00
# Load Growth  0.09 %, time: 12:00
# NV
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 1521.0 MW, time: 12:00
# New Peak     1522.0 MW, time: 12:00
# New Supply   1.0 MW, time: 10:00
# Load Growth  0.06 %, time: 12:00
# OK
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 2009.0 MW, time: 12:00
# New Peak     2010.0 MW, time: 12:00
# New Supply   2.0 MW, time: 10:00
# Load Growth  0.08 %, time: 12:00
# OR
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 1282.0 MW, time: 12:00
# New Peak     1283.0 MW, time: 12:00
# New Supply   1.0 MW, time: 10:00
# Load Growth  0.08 %, time: 12:00
# RI
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 408.0 MW, time: 11:00
# New Peak     408.0 MW, time: 11:00
# New Supply   1.0 MW, time: 10:00
# Load Growth  0.14 %, time: 11:00
# SC
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 2827.0 MW, time: 12:00
# New Peak     2829.0 MW, time: 12:00
# New Supply   2.0 MW, time: 10:00
# Load Growth  0.06 %, time: 12:00
# SD
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 259.0 MW, time: 11:00
# New Peak     260.0 MW, time: 11:00
# New Supply   0.0 MW, time: 9:00
# Load Growth  0.13 %, time: 11:00
# TN
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 3393.0 MW, time: 11:00
# New Peak     3395.0 MW, time: 11:00
# New Supply   2.0 MW, time: 10:00
# Load Growth  0.07 %, time: 11:00
# UT
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 1108.0 MW, time: 12:00
# New Peak     1109.0 MW, time: 12:00
# New Supply   1.0 MW, time: 7:00
# Load Growth  0.1 %, time: 12:00
# VA
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 3580.0 MW, time: 11:00
# New Peak     3582.0 MW, time: 11:00
# New Supply   3.0 MW, time: 10:00
# Load Growth  0.07 %, time: 11:00
# VT
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 135.0 MW, time: 11:00
# New Peak     135.0 MW, time: 11:00
# New Supply   0.0 MW, time: 10:00
# Load Growth  0.13 %, time: 11:00
# WA
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 2130.0 MW, time: 11:00
# New Peak     2132.0 MW, time: 11:00
# New Supply   2.0 MW, time: 10:00
# Load Growth  0.08 %, time: 11:00
# WI
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 2333.0 MW, time: 11:00
# New Peak     2337.0 MW, time: 11:00
# New Supply   4.0 MW, time: 10:00
# Load Growth  0.17 %, time: 11:00
# WV
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 868.0 MW, time: 12:00
# New Peak     869.0 MW, time: 12:00
# New Supply   1.0 MW, time: 10:00
# Load Growth  0.11 %, time: 12:00
# WY
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 150.0 MW, time: 12:00
# New Peak     150.0 MW, time: 12:00
# New Supply   0.0 MW, time: 7:00
# Load Growth  0.13 %, time: 12:00
# 2027
# NY
# Total Energy supply added from current energy consumption = 4.2  TWh
# Current Peak 8181.0 MW, time: 11:00
# New Peak     8809.0 MW, time: 11:00
# New Supply   649.0 MW, time: 10:00
# Load Growth  7.69 %, time: 11:00
# CA
# Total Energy supply added from current energy consumption = 7.7  TWh
# Current Peak 17267.0 MW, time: 12:00
# New Peak     18423.0 MW, time: 12:00
# New Supply   1321.0 MW, time: 9:00
# Load Growth  6.7 %, time: 12:00
# IL
# Total Energy supply added from current energy consumption = 0.2  TWh
# Current Peak 5403.0 MW, time: 12:00
# New Peak     5428.0 MW, time: 11:00
# New Supply   28.0 MW, time: 7:00
# Load Growth  0.49 %, time: 11:00
# OH
# Total Energy supply added from current energy consumption = 0.1  TWh
# Current Peak 5586.0 MW, time: 11:00
# New Peak     5604.0 MW, time: 11:00
# New Supply   19.0 MW, time: 10:00
# Load Growth  0.33 %, time: 11:00
# MI
# Total Energy supply added from current energy consumption = 0.1  TWh
# Current Peak 3529.0 MW, time: 12:00
# New Peak     3549.0 MW, time: 12:00
# New Supply   23.0 MW, time: 7:00
# Load Growth  0.55 %, time: 12:00
# TX
# Total Energy supply added from current energy consumption = 0.1  TWh
# Current Peak 15412.0 MW, time: 12:00
# New Peak     15433.0 MW, time: 12:00
# New Supply   23.0 MW, time: 10:00
# Load Growth  0.14 %, time: 12:00
# PA
# Total Energy supply added from current energy consumption = 0.1  TWh
# Current Peak 5709.0 MW, time: 11:00
# New Peak     5724.0 MW, time: 11:00
# New Supply   15.0 MW, time: 10:00
# Load Growth  0.26 %, time: 11:00
# MA
# Total Energy supply added from current energy consumption = 0.1  TWh
# Current Peak 3304.0 MW, time: 11:00
# New Peak     3315.0 MW, time: 11:00
# New Supply   12.0 MW, time: 9:00
# Load Growth  0.34 %, time: 11:00
# FL
# Total Energy supply added from current energy consumption = 0.2  TWh
# Current Peak 13360.0 MW, time: 12:00
# New Peak     13387.0 MW, time: 12:00
# New Supply   30.0 MW, time: 11:00
# Load Growth  0.2 %, time: 12:00
# AL
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 2171.0 MW, time: 12:00
# New Peak     2174.0 MW, time: 12:00
# New Supply   4.0 MW, time: 10:00
# Load Growth  0.15 %, time: 12:00
# AR
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 1508.0 MW, time: 12:00
# New Peak     1511.0 MW, time: 12:00
# New Supply   3.0 MW, time: 10:00
# Load Growth  0.18 %, time: 12:00
# AZ
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 3169.0 MW, time: 13:00
# New Peak     3173.0 MW, time: 13:00
# New Supply   4.0 MW, time: 10:00
# Load Growth  0.11 %, time: 13:00
# CO
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 2154.0 MW, time: 11:00
# New Peak     2160.0 MW, time: 11:00
# New Supply   7.0 MW, time: 7:00
# Load Growth  0.28 %, time: 11:00
# CT
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 1463.0 MW, time: 11:00
# New Peak     1466.0 MW, time: 11:00
# New Supply   4.0 MW, time: 10:00
# Load Growth  0.27 %, time: 11:00
# DC
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 673.0 MW, time: 10:00
# New Peak     674.0 MW, time: 10:00
# New Supply   1.0 MW, time: 10:00
# Load Growth  0.13 %, time: 10:00
# DE
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 342.0 MW, time: 12:00
# New Peak     343.0 MW, time: 12:00
# New Supply   1.0 MW, time: 10:00
# Load Growth  0.25 %, time: 12:00
# GA
# Total Energy supply added from current energy consumption = 0.1  TWh
# Current Peak 4972.0 MW, time: 12:00
# New Peak     4980.0 MW, time: 12:00
# New Supply   9.0 MW, time: 10:00
# Load Growth  0.16 %, time: 12:00
# IA
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 1090.0 MW, time: 11:00
# New Peak     1094.0 MW, time: 11:00
# New Supply   4.0 MW, time: 9:00
# Load Growth  0.36 %, time: 11:00
# ID
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 574.0 MW, time: 12:00
# New Peak     576.0 MW, time: 12:00
# New Supply   2.0 MW, time: 9:00
# Load Growth  0.3 %, time: 12:00
# IN
# Total Energy supply added from current energy consumption = 0.1  TWh
# Current Peak 2791.0 MW, time: 12:00
# New Peak     2799.0 MW, time: 12:00
# New Supply   9.0 MW, time: 10:00
# Load Growth  0.28 %, time: 12:00
# KS
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 1380.0 MW, time: 12:00
# New Peak     1383.0 MW, time: 12:00
# New Supply   4.0 MW, time: 9:00
# Load Growth  0.22 %, time: 12:00
# KY
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 1615.0 MW, time: 11:00
# New Peak     1618.0 MW, time: 11:00
# New Supply   4.0 MW, time: 9:00
# Load Growth  0.22 %, time: 11:00
# LA
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 2528.0 MW, time: 12:00
# New Peak     2532.0 MW, time: 12:00
# New Supply   4.0 MW, time: 10:00
# Load Growth  0.15 %, time: 12:00
# MD
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 2406.0 MW, time: 11:00
# New Peak     2411.0 MW, time: 11:00
# New Supply   6.0 MW, time: 10:00
# Load Growth  0.22 %, time: 11:00
# ME
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 522.0 MW, time: 11:00
# New Peak     524.0 MW, time: 11:00
# New Supply   2.0 MW, time: 10:00
# Load Growth  0.32 %, time: 11:00
# MN
# Total Energy supply added from current energy consumption = 0.1  TWh
# Current Peak 2203.0 MW, time: 11:00
# New Peak     2212.0 MW, time: 11:00
# New Supply   10.0 MW, time: 9:00
# Load Growth  0.43 %, time: 11:00
# MO
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 3087.0 MW, time: 11:00
# New Peak     3094.0 MW, time: 11:00
# New Supply   7.0 MW, time: 10:00
# Load Growth  0.21 %, time: 11:00
# MS
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 1185.0 MW, time: 12:00
# New Peak     1187.0 MW, time: 12:00
# New Supply   2.0 MW, time: 10:00
# Load Growth  0.16 %, time: 12:00
# MT
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 274.0 MW, time: 11:00
# New Peak     275.0 MW, time: 11:00
# New Supply   1.0 MW, time: 9:00
# Load Growth  0.46 %, time: 11:00
# NC
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 4416.0 MW, time: 12:00
# New Peak     4424.0 MW, time: 12:00
# New Supply   8.0 MW, time: 10:00
# Load Growth  0.17 %, time: 12:00
# ND
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 222.0 MW, time: 10:00
# New Peak     223.0 MW, time: 10:00
# New Supply   1.0 MW, time: 10:00
# Load Growth  0.36 %, time: 10:00
# NE
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 804.0 MW, time: 11:00
# New Peak     806.0 MW, time: 11:00
# New Supply   3.0 MW, time: 9:00
# Load Growth  0.35 %, time: 11:00
# NH
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 485.0 MW, time: 11:00
# New Peak     487.0 MW, time: 11:00
# New Supply   2.0 MW, time: 10:00
# Load Growth  0.32 %, time: 11:00
# NJ
# Total Energy supply added from current energy consumption = 0.1  TWh
# Current Peak 4029.0 MW, time: 11:00
# New Peak     4040.0 MW, time: 11:00
# New Supply   12.0 MW, time: 10:00
# Load Growth  0.28 %, time: 11:00
# NM
# ...
# Load Growth  23.92 %, time: 11:00
# MD
# Total Energy supply added from current energy consumption = 4.9  TWh
# Current Peak 2406.0 MW, time: 11:00
# New Peak     3166.0 MW, time: 11:00
# New Supply   791.0 MW, time: 10:00
# Load Growth  31.58 %, time: 11:00
# ME
# Total Energy supply added from current energy consumption = 1.6  TWh
# Current Peak 522.0 MW, time: 11:00
# New Peak     768.0 MW, time: 10:00
# New Supply   249.0 MW, time: 10:00
# Load Growth  47.94 %, time: 10:00
# MN
# Total Energy supply added from current energy consumption = 9.5  TWh
# Current Peak 2203.0 MW, time: 11:00
# New Peak     3602.0 MW, time: 10:00
# New Supply   1452.0 MW, time: 9:00
# Load Growth  66.2 %, time: 10:00
# MO
# Total Energy supply added from current energy consumption = 5.8  TWh
# Current Peak 3087.0 MW, time: 11:00
# New Peak     4002.0 MW, time: 11:00
# New Supply   951.0 MW, time: 10:00
# Load Growth  29.63 %, time: 11:00
# MS
# Total Energy supply added from current energy consumption = 1.7  TWh
# Current Peak 1185.0 MW, time: 12:00
# New Peak     1464.0 MW, time: 11:00
# New Supply   305.0 MW, time: 10:00
# Load Growth  25.63 %, time: 11:00
# MT
# Total Energy supply added from current energy consumption = 1.3  TWh
# Current Peak 274.0 MW, time: 11:00
# New Peak     466.0 MW, time: 10:00
# New Supply   196.0 MW, time: 9:00
# Load Growth  70.92 %, time: 10:00
# NC
# Total Energy supply added from current energy consumption = 6.8  TWh
# Current Peak 4416.0 MW, time: 12:00
# New Peak     5560.0 MW, time: 11:00
# New Supply   1199.0 MW, time: 10:00
# Load Growth  26.61 %, time: 11:00
# ND
# Total Energy supply added from current energy consumption = 0.7  TWh
# Current Peak 222.0 MW, time: 10:00
# New Peak     338.0 MW, time: 10:00
# New Supply   116.0 MW, time: 10:00
# Load Growth  52.41 %, time: 10:00
# NE
# Total Energy supply added from current energy consumption = 2.7  TWh
# Current Peak 804.0 MW, time: 11:00
# New Peak     1213.0 MW, time: 10:00
# New Supply   426.0 MW, time: 9:00
# Load Growth  53.81 %, time: 10:00
# NH
# Total Energy supply added from current energy consumption = 1.5  TWh
# Current Peak 485.0 MW, time: 11:00
# New Peak     709.0 MW, time: 11:00
# New Supply   229.0 MW, time: 10:00
# Load Growth  45.99 %, time: 11:00
# NJ
# Total Energy supply added from current energy consumption = 10.9  TWh
# Current Peak 4029.0 MW, time: 11:00
# New Peak     5641.0 MW, time: 11:00
# New Supply   1678.0 MW, time: 10:00
# Load Growth  40.01 %, time: 11:00
# NM
# Total Energy supply added from current energy consumption = 2.0  TWh
# Current Peak 822.0 MW, time: 12:00
# New Peak     1119.0 MW, time: 11:00
# New Supply   317.0 MW, time: 9:00
# Load Growth  36.53 %, time: 11:00
# NV
# Total Energy supply added from current energy consumption = 2.4  TWh
# Current Peak 1521.0 MW, time: 12:00
# New Peak     1898.0 MW, time: 11:00
# New Supply   409.0 MW, time: 10:00
# Load Growth  26.9 %, time: 11:00
# OK
# Total Energy supply added from current energy consumption = 4.2  TWh
# Current Peak 2009.0 MW, time: 12:00
# New Peak     2633.0 MW, time: 11:00
# New Supply   683.0 MW, time: 10:00
# Load Growth  32.25 %, time: 11:00
# OR
# Total Energy supply added from current energy consumption = 2.7  TWh
# Current Peak 1282.0 MW, time: 12:00
# New Peak     1721.0 MW, time: 11:00
# New Supply   461.0 MW, time: 10:00
# Load Growth  34.78 %, time: 11:00
# RI
# Total Energy supply added from current energy consumption = 1.5  TWh
# Current Peak 408.0 MW, time: 11:00
# New Peak     627.0 MW, time: 10:00
# New Supply   227.0 MW, time: 10:00
# Load Growth  56.61 %, time: 10:00
# SC
# Total Energy supply added from current energy consumption = 4.3  TWh
# Current Peak 2827.0 MW, time: 12:00
# New Peak     3569.0 MW, time: 11:00
# New Supply   774.0 MW, time: 10:00
# Load Growth  27.08 %, time: 11:00
# SD
# Total Energy supply added from current energy consumption = 0.9  TWh
# Current Peak 259.0 MW, time: 11:00
# New Peak     392.0 MW, time: 10:00
# New Supply   140.0 MW, time: 9:00
# Load Growth  54.01 %, time: 10:00
# TN
# Total Energy supply added from current energy consumption = 5.4  TWh
# Current Peak 3393.0 MW, time: 11:00
# New Peak     4259.0 MW, time: 11:00
# New Supply   918.0 MW, time: 10:00
# Load Growth  25.53 %, time: 11:00
# UT
# Total Energy supply added from current energy consumption = 3.4  TWh
# Current Peak 1108.0 MW, time: 12:00
# New Peak     1578.0 MW, time: 10:00
# New Supply   520.0 MW, time: 7:00
# Load Growth  46.81 %, time: 10:00
# VA
# Total Energy supply added from current energy consumption = 5.8  TWh
# Current Peak 3580.0 MW, time: 11:00
# New Peak     4534.0 MW, time: 11:00
# New Supply   984.0 MW, time: 10:00
# Load Growth  26.66 %, time: 11:00
# VT
# Total Energy supply added from current energy consumption = 0.5  TWh
# Current Peak 135.0 MW, time: 11:00
# New Peak     200.0 MW, time: 11:00
# New Supply   67.0 MW, time: 10:00
# Load Growth  48.23 %, time: 11:00
# WA
# Total Energy supply added from current energy consumption = 4.2  TWh
# Current Peak 2130.0 MW, time: 11:00
# New Peak     2821.0 MW, time: 10:00
# New Supply   706.0 MW, time: 10:00
# Load Growth  33.41 %, time: 10:00
# WI
# Total Energy supply added from current energy consumption = 10.2  TWh
# Current Peak 2333.0 MW, time: 11:00
# New Peak     3826.0 MW, time: 10:00
# New Supply   1541.0 MW, time: 10:00
# Load Growth  67.48 %, time: 10:00
# WV
# Total Energy supply added from current energy consumption = 2.5  TWh
# Current Peak 868.0 MW, time: 12:00
# New Peak     1266.0 MW, time: 11:00
# New Supply   421.0 MW, time: 10:00
# Load Growth  47.13 %, time: 11:00
# WY
# Total Energy supply added from current energy consumption = 0.6  TWh
# Current Peak 150.0 MW, time: 12:00
# New Peak     233.0 MW, time: 10:00
# New Supply   91.0 MW, time: 7:00
# Load Growth  59.16 %, time: 10:00
# 2050
# NY
# Total Energy supply added from current energy consumption = 22.9  TWh
# Current Peak 8181.0 MW, time: 11:00
# New Peak     11643.0 MW, time: 11:00
# New Supply   3571.0 MW, time: 10:00
# Load Growth  42.32 %, time: 11:00
# CA
# Total Energy supply added from current energy consumption = 42.9  TWh
# Current Peak 17267.0 MW, time: 12:00
# New Peak     23673.0 MW, time: 12:00
# New Supply   7319.0 MW, time: 9:00
# Load Growth  37.11 %, time: 12:00
# IL
# Total Energy supply added from current energy consumption = 19.3  TWh
# Current Peak 5403.0 MW, time: 12:00
# New Peak     8181.0 MW, time: 10:00
# New Supply   2914.0 MW, time: 7:00
# Load Growth  55.01 %, time: 10:00
# OH
# Total Energy supply added from current energy consumption = 17.6  TWh
# Current Peak 5586.0 MW, time: 11:00
# New Peak     8253.0 MW, time: 11:00
# New Supply   2792.0 MW, time: 10:00
# Load Growth  47.75 %, time: 11:00
# MI
# Total Energy supply added from current energy consumption = 15.6  TWh
# Current Peak 3529.0 MW, time: 12:00
# New Peak     5811.0 MW, time: 10:00
# New Supply   2422.0 MW, time: 7:00
# Load Growth  69.61 %, time: 10:00
# TX
# Total Energy supply added from current energy consumption = 18.5  TWh
# Current Peak 15412.0 MW, time: 12:00
# New Peak     18518.0 MW, time: 11:00
# New Supply   3365.0 MW, time: 10:00
# Load Growth  21.76 %, time: 11:00
# PA
# Total Energy supply added from current energy consumption = 13.7  TWh
# Current Peak 5709.0 MW, time: 11:00
# New Peak     7854.0 MW, time: 11:00
# New Supply   2212.0 MW, time: 10:00
# Load Growth  37.58 %, time: 11:00
# MA
# Total Energy supply added from current energy consumption = 8.2  TWh
# Current Peak 3304.0 MW, time: 11:00
# New Peak     4494.0 MW, time: 10:00
# New Supply   1222.0 MW, time: 9:00
# Load Growth  37.32 %, time: 10:00
# FL
# Total Energy supply added from current energy consumption = 16.0  TWh
# Current Peak 13360.0 MW, time: 12:00
# New Peak     16382.0 MW, time: 11:00
# New Supply   3111.0 MW, time: 11:00
# Load Growth  23.45 %, time: 11:00
# AL
# Total Energy supply added from current energy consumption = 2.9  TWh
# Current Peak 2171.0 MW, time: 12:00
# New Peak     2662.0 MW, time: 11:00
# New Supply   520.0 MW, time: 10:00
# Load Growth  23.78 %, time: 11:00
# AR
# Total Energy supply added from current energy consumption = 2.8  TWh
# Current Peak 1508.0 MW, time: 12:00
# New Peak     1941.0 MW, time: 11:00
# New Supply   459.0 MW, time: 10:00
# Load Growth  29.44 %, time: 11:00
# AZ
# Total Energy supply added from current energy consumption = 3.4  TWh
# Current Peak 3169.0 MW, time: 13:00
# New Peak     3723.0 MW, time: 12:00
# New Supply   630.0 MW, time: 10:00
# Load Growth  18.12 %, time: 12:00
# CO
# Total Energy supply added from current energy consumption = 6.1  TWh
# Current Peak 2154.0 MW, time: 11:00
# New Peak     3013.0 MW, time: 11:00
# New Supply   956.0 MW, time: 7:00
# Load Growth  39.87 %, time: 11:00
# CT
# Total Energy supply added from current energy consumption = 3.8  TWh
# Current Peak 1463.0 MW, time: 11:00
# New Peak     2028.0 MW, time: 10:00
# New Supply   585.0 MW, time: 10:00
# Load Growth  40.52 %, time: 10:00
# DC
# Total Energy supply added from current energy consumption = 0.7  TWh
# Current Peak 673.0 MW, time: 10:00
# New Peak     795.0 MW, time: 10:00
# New Supply   122.0 MW, time: 10:00
# Load Growth  18.17 %, time: 10:00
# DE
# Total Energy supply added from current energy consumption = 0.9  TWh
# Current Peak 342.0 MW, time: 12:00
# New Peak     477.0 MW, time: 11:00
# New Supply   140.0 MW, time: 10:00
# Load Growth  39.58 %, time: 11:00
# GA
# Total Energy supply added from current energy consumption = 7.3  TWh
# Current Peak 4972.0 MW, time: 12:00
# New Peak     6172.0 MW, time: 11:00
# New Supply   1292.0 MW, time: 10:00
# Load Growth  25.41 %, time: 11:00
# IA
# Total Energy supply added from current energy consumption = 3.9  TWh
# Current Peak 1090.0 MW, time: 11:00
# New Peak     1660.0 MW, time: 10:00
# New Supply   588.0 MW, time: 9:00
# Load Growth  54.82 %, time: 10:00
# ID
# Total Energy supply added from current energy consumption = 2.0  TWh
# Current Peak 574.0 MW, time: 12:00
# New Peak     849.0 MW, time: 10:00
# New Supply   294.0 MW, time: 9:00
# Load Growth  52.73 %, time: 10:00
# IN
# Total Energy supply added from current energy consumption = 8.1  TWh
# Current Peak 2791.0 MW, time: 12:00
# New Peak     4020.0 MW, time: 11:00
# New Supply   1288.0 MW, time: 10:00
# Load Growth  44.26 %, time: 11:00
# KS
# Total Energy supply added from current energy consumption = 3.4  TWh
# Current Peak 1380.0 MW, time: 12:00
# New Peak     1864.0 MW, time: 11:00
# New Supply   523.0 MW, time: 9:00
# Load Growth  35.34 %, time: 11:00
# KY
# Total Energy supply added from current energy consumption = 3.4  TWh
# Current Peak 1615.0 MW, time: 11:00
# New Peak     2178.0 MW, time: 10:00
# New Supply   593.0 MW, time: 9:00
# Load Growth  35.9 %, time: 10:00
# LA
# Total Energy supply added from current energy consumption = 3.4  TWh
# Current Peak 2528.0 MW, time: 12:00
# New Peak     3119.0 MW, time: 11:00
# New Supply   606.0 MW, time: 10:00
# Load Growth  23.93 %, time: 11:00
# MD
# Total Energy supply added from current energy consumption = 4.9  TWh
# Current Peak 2406.0 MW, time: 11:00
# New Peak     3166.0 MW, time: 11:00
# New Supply   792.0 MW, time: 10:00
# Load Growth  31.6 %, time: 11:00
# ME
# Total Energy supply added from current energy consumption = 1.6  TWh
# Current Peak 522.0 MW, time: 11:00
# New Peak     768.0 MW, time: 10:00
# New Supply   249.0 MW, time: 10:00
# Load Growth  47.97 %, time: 10:00
# MN
# Total Energy supply added from current energy consumption = 9.5  TWh
# Current Peak 2203.0 MW, time: 11:00
# New Peak     3603.0 MW, time: 10:00
# New Supply   1453.0 MW, time: 9:00
# Load Growth  66.24 %, time: 10:00
# MO
# Total Energy supply added from current energy consumption = 5.8  TWh
# Current Peak 3087.0 MW, time: 11:00
# New Peak     4003.0 MW, time: 11:00
# New Supply   951.0 MW, time: 10:00
# Load Growth  29.65 %, time: 11:00
# MS
# Total Energy supply added from current energy consumption = 1.7  TWh
# Current Peak 1185.0 MW, time: 12:00
# New Peak     1464.0 MW, time: 11:00
# New Supply   305.0 MW, time: 10:00
# Load Growth  25.64 %, time: 11:00
# MT
# Total Energy supply added from current energy consumption = 1.3  TWh
# Current Peak 274.0 MW, time: 11:00
# New Peak     466.0 MW, time: 10:00
# New Supply   196.0 MW, time: 9:00
# Load Growth  70.96 %, time: 10:00
# NC
# Total Energy supply added from current energy consumption = 6.8  TWh
# Current Peak 4416.0 MW, time: 12:00
# New Peak     5561.0 MW, time: 11:00
# New Supply   1200.0 MW, time: 10:00
# Load Growth  26.62 %, time: 11:00
# ND
# Total Energy supply added from current energy consumption = 0.7  TWh
# Current Peak 222.0 MW, time: 10:00
# New Peak     338.0 MW, time: 10:00
# New Supply   116.0 MW, time: 10:00
# Load Growth  52.44 %, time: 10:00
# NE
# Total Energy supply added from current energy consumption = 2.8  TWh
# Current Peak 804.0 MW, time: 11:00
# New Peak     1213.0 MW, time: 10:00
# New Supply   426.0 MW, time: 9:00
# Load Growth  53.85 %, time: 10:00
# NH
# Total Energy supply added from current energy consumption = 1.5  TWh
# Current Peak 485.0 MW, time: 11:00
# New Peak     709.0 MW, time: 11:00
# New Supply   229.0 MW, time: 10:00
# Load Growth  46.02 %, time: 11:00
# NJ
# Total Energy supply added from current energy consumption = 10.9  TWh
# Current Peak 4029.0 MW, time: 11:00
# New Peak     5642.0 MW, time: 11:00
# New Supply   1679.0 MW, time: 10:00
# Load Growth  40.03 %, time: 11:00
# NM
# Total Energy supply added from current energy consumption = 2.0  TWh
# Current Peak 822.0 MW, time: 12:00
# New Peak     1120.0 MW, time: 11:00
# New Supply   318.0 MW, time: 9:00
# Load Growth  36.55 %, time: 11:00
# NV
# Total Energy supply added from current energy consumption = 2.4  TWh
# Current Peak 1521.0 MW, time: 12:00
# New Peak     1898.0 MW, time: 11:00
# New Supply   409.0 MW, time: 10:00
# Load Growth  26.92 %, time: 11:00
# OK
# Total Energy supply added from current energy consumption = 4.2  TWh
# Current Peak 2009.0 MW, time: 12:00
# New Peak     2634.0 MW, time: 11:00
# New Supply   683.0 MW, time: 10:00
# Load Growth  32.27 %, time: 11:00
# OR
# Total Energy supply added from current energy consumption = 2.7  TWh
# Current Peak 1282.0 MW, time: 12:00
# New Peak     1721.0 MW, time: 11:00
# New Supply   461.0 MW, time: 10:00
# Load Growth  34.8 %, time: 11:00
# RI
# Total Energy supply added from current energy consumption = 1.5  TWh
# Current Peak 408.0 MW, time: 11:00
# New Peak     627.0 MW, time: 10:00
# New Supply   227.0 MW, time: 10:00
# Load Growth  56.64 %, time: 10:00
# SC
# Total Energy supply added from current energy consumption = 4.3  TWh
# Current Peak 2827.0 MW, time: 12:00
# New Peak     3570.0 MW, time: 11:00
# New Supply   774.0 MW, time: 10:00
# Load Growth  27.09 %, time: 11:00
# SD
# Total Energy supply added from current energy consumption = 0.9  TWh
# Current Peak 259.0 MW, time: 11:00
# New Peak     392.0 MW, time: 10:00
# New Supply   140.0 MW, time: 9:00
# Load Growth  54.04 %, time: 10:00
# TN
# Total Energy supply added from current energy consumption = 5.4  TWh
# Current Peak 3393.0 MW, time: 11:00
# New Peak     4260.0 MW, time: 11:00
# New Supply   918.0 MW, time: 10:00
# Load Growth  25.55 %, time: 11:00
# UT
# Total Energy supply added from current energy consumption = 3.4  TWh
# Current Peak 1108.0 MW, time: 12:00
# New Peak     1579.0 MW, time: 10:00
# New Supply   521.0 MW, time: 7:00
# Load Growth  46.84 %, time: 10:00
# VA
# Total Energy supply added from current energy consumption = 5.8  TWh
# Current Peak 3580.0 MW, time: 11:00
# New Peak     4535.0 MW, time: 11:00
# New Supply   985.0 MW, time: 10:00
# Load Growth  26.68 %, time: 11:00
# VT
# Total Energy supply added from current energy consumption = 0.5  TWh
# Current Peak 135.0 MW, time: 11:00
# New Peak     200.0 MW, time: 11:00
# New Supply   67.0 MW, time: 10:00
# Load Growth  48.26 %, time: 11:00
# WA
# Total Energy supply added from current energy consumption = 4.2  TWh
# Current Peak 2130.0 MW, time: 11:00
# New Peak     2821.0 MW, time: 10:00
# New Supply   707.0 MW, time: 10:00
# Load Growth  33.43 %, time: 10:00
# WI
# Total Energy supply added from current energy consumption = 10.2  TWh
# Current Peak 2333.0 MW, time: 11:00
# New Peak     3827.0 MW, time: 10:00
# New Supply   1542.0 MW, time: 10:00
# Load Growth  67.52 %, time: 10:00
# WV
# Total Energy supply added from current energy consumption = 2.5  TWh
# Current Peak 868.0 MW, time: 12:00
# New Peak     1266.0 MW, time: 11:00
# New Supply   421.0 MW, time: 10:00
# Load Growth  47.15 %, time: 11:00
# WY
# Total Energy supply added from current energy consumption = 0.6  TWh
# Current Peak 150.0 MW, time: 12:00
# New Peak     233.0 MW, time: 10:00
# New Supply   91.0 MW, time: 7:00
# Load Growth  59.19 %, time: 10:00

# %% [markdown]
# # Make plots of peaks/energy over years for each state

# %%
state_summary_list = {}

for state in com_states:
    print(state)
    
    state_summary_list[state] = {"New Peak" : [], "New Supply" : [], "Total Energy Added" : []}
    
    for study_year in year_range:
        print(study_year)
        str_study_year = str(study_year)
    
        state_summary_list[state]["New Peak"].append(results_comm[str_study_year][state]["New Peak"])
        state_summary_list[state]["New Supply"].append(results_comm[str_study_year][state]["New Supply"])
        state_summary_list[state]["Total Energy Added"].append(results_comm[str_study_year][state]["Total Energy Supply Added from Current Energy Consumption"])
# Out:
# NY
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2047
# 2048
# 2049
# 2050
# CA
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2047
# 2048
# 2049
# 2050
# IL
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2047
# 2048
# 2049
# 2050
# OH
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2047
# 2048
# 2049
# 2050
# MI
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2047
# 2048
# 2049
# 2050
# TX
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2047
# 2048
# 2049
# 2050
# PA
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2047
# 2048
# 2049
# 2050
# MA
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2047
# 2048
# 2049
# 2050
# FL
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2047
# 2048
# 2049
# 2050
# AL
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2047
# 2048
# 2049
# 2050
# AR
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2047
# 2048
# 2049
# 2050
# AZ
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2047
# 2048
# 2049
# 2050
# CO
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2047
# 2048
# 2049
# 2050
# CT
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2047
# 2048
# 2049
# 2050
# DC
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2047
# 2048
# 2049
# 2050
# DE
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2047
# 2048
# 2049
# 2050
# GA
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2047
# 2048
# 2049
# 2050
# IA
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2047
# 2048
# 2049
# 2050
# ID
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2047
# 2048
# 2049
# 2050
# IN
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2047
# 2048
# 2049
# 2050
# KS
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2047
# 2048
# 2049
# 2050
# KY
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2047
# 2048
# 2049
# 2050
# LA
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2047
# 2048
# 2049
# 2050
# MD
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2047
# 2048
# 2049
# 2050
# ME
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2047
# 2048
# 2049
# 2050
# MN
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2047
# 2048
# 2049
# 2050
# MO
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2047
# 2048
# 2049
# 2050
# MS
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2047
# 2048
# 2049
# 2050
# MT
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2047
# 2048
# 2049
# 2050
# NC
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2047
# 2048
# 2049
# 2050
# ND
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2047
# 2048
# 2049
# 2050
# NE
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2047
# 2048
# 2049
# 2050
# NH
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2047
# 2048
# 2049
# 2050
# NJ
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2047
# 2048
# 2049
# 2050
# NM
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2047
# 2048
# 2049
# 2050
# NV
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2047
# 2048
# 2049
# 2050
# OK
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2047
# 2048
# 2049
# 2050
# OR
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2047
# 2048
# 2049
# 2050
# RI
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2047
# 2048
# 2049
# 2050
# SC
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2047
# 2048
# 2049
# 2050
# SD
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2047
# 2048
# 2049
# 2050
# TN
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2047
# 2048
# 2049
# 2050
# UT
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2047
# 2048
# 2049
# 2050
# VA
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2047
# 2048
# 2049
# 2050
# VT
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2047
# 2048
# 2049
# 2050
# WA
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2047
# 2048
# 2049
# 2050
# WI
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2047
# 2048
# 2049
# 2050
# WV
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2047
# 2048
# 2049
# 2050
# WY
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2047
# 2048
# 2049
# 2050

# %% [markdown]
# # Aggregate "all other" states
# ### can I aggregate after this calculation? can "new peak" be added up or should Imain_statesregate loadshapes first then calculate peak?
#
# ### I'm going to add the peaks after the loadshape analysis at a state level. That makes more sense to me right now. Need to make sure to check w/ Dave

# %%
main_states = ["NY", "CA", "IL", "OH", "MI", "TX", "PA", "FL"]
other_states = [x for x in com_states if x not in main_states]

# %%
new_peak_all_others = []
new_supply_all_others = []
total_e_added_all_others = []
    
for state in other_states:
    new_peak_all_others.append(state_summary_list[state]["New Peak"])
    new_supply_all_others.append(state_summary_list[state]["New Supply"])
    total_e_added_all_others.append(state_summary_list[state]["Total Energy Added"])

state_summary_list["All Others"] = {}

state_summary_list["All Others"]["New Peak"] = np.asarray(new_peak_all_others).sum(axis=0)
state_summary_list["All Others"]["New Supply"] = np.asarray(new_supply_all_others).sum(axis=0)
state_summary_list["All Others"]["Total Energy Added"] = np.asarray(total_e_added_all_others).sum(axis=0)

# %% [markdown]
# # Plot

# %%
save_plots = False

# %%
plot_states = main_states + ["All Others"]

# %% [markdown]
# ### New Peak

# %%
for state in plot_states:
    plt.plot(year_range, state_summary_list[state]["New Peak"], label=state)
plt.title(f"New Peak for Top States (Commercial)")   
plt.ylabel("Power (MW)")
plt.xlabel("Year")
plt.legend()

if save_plots:
    plt.savefig("com_new_peak_states.pdf", dpi=150)

plt.show()

# %%
list_plot = [state_summary_list[state]["New Peak"] for state in plot_states]

plt.stackplot(year_range, list_plot, labels=plot_states)
plt.title(f"New Peak for Top States (Commercial)")   
plt.ylabel("Power (MW)")
plt.xlabel("Year")
plt.legend(loc="upper left")

if save_plots:
    plt.savefig("com_new_peak_states_stack.pdf", dpi=150)
    
plt.show()

# %% [markdown]
# ### New Supply

# %%
for state in plot_states:
    plt.plot(year_range, state_summary_list[state]["New Supply"], label=state)
plt.title(f"New Supply for Top States (Commercial)")   
plt.ylabel("Power (MW)")
plt.xlabel("Year")
plt.legend()

if save_plots:
    plt.savefig("com_new_supply_states.pdf", dpi=150)
    
plt.show()

# %%
list_plot = [state_summary_list[state]["New Supply"] for state in plot_states]

plt.stackplot(year_range, list_plot, labels=plot_states)
plt.title(f"New Supply for Top States (Commercial)")   
plt.ylabel("Power (MW)")
plt.xlabel("Year")
plt.legend(loc="upper left")

if save_plots:
    plt.savefig("com_new_supply_states_stack.pdf", dpi=150)
    
plt.show()

# %% [markdown]
# ### Total Energy Added

# %%
for state in plot_states:
    plt.plot(year_range, state_summary_list[state]["Total Energy Added"], label=state)
plt.title(f"Total Energy Supply Added for Top States (Commercial)")   
plt.ylabel("Energy (TWh)")
plt.xlabel("Year")
plt.legend()

if save_plots:
    plt.savefig("com_energy_supply_states.pdf", dpi=150)
    
plt.show()

# %%
list_plot = [state_summary_list[state]["Total Energy Added"] for state in plot_states]

plt.stackplot(year_range, list_plot, labels=plot_states)
plt.title(f"Total Energy Supply Added for Top States (Commercial)")   
plt.ylabel("Energy (TWh)")
plt.xlabel("Year")
plt.legend(loc="upper left")

if save_plots:
    plt.savefig("com_energy_supply_states_stack.pdf", dpi=150)
    
plt.show()

# %% [markdown]
# ## Plot by RTO
