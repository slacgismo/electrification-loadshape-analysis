# %% [markdown]
# # Loadshape Electrification Analysis for Commercial Sector by State
# ## Using NREL's ComStock, 2023 release of amy_2018_v1

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import calendar
import datetime as dt
import seaborn as sns
sns.set_theme()

from sg2t.io.loadshapes.nrel.api import API
from sg2t.io.loadshapes.nrel.naming import BUILDING_TYPES
from sg2t.utils.timeseries import Timeseries

from analysis_utils import format_columns_df, sigmoid, loadshape_analysis

# %% [markdown]
# # Loop over: years, states, building types

# %%
sector = "Comstock"

# %%
year_range = np.arange(2023, 2051)

# %% [markdown]
# ## Get data for all top states
# ### do all for each residential and commercial (incl. MA and FL in both)
# - Residential:  New York, Illinois, California, Ohio, Michigan, Texas, Pennsylvania, and Massachusetts
# - Commercial: New York, Illinois, California, Ohio, Michigan, Texas, Pennsylvania, and Florida
#
# Divide states into three categories:
# - those with a set target year and that have started adopting: CA, NY, MA, IL, MI, FL
# - those with a set target year and will adopt: PA?
# - those that have no target set (follow the market): OH, TX

# %% [markdown]
# ## Import input values

# %%
with open('inputs.json', 'r') as openfile:
     inputs = json.load(openfile)

# %%
com_states = list(inputs["State Target Year"].keys())
com_states.pop(7) # do not take MA for commercial analysis
com_states
# Out:
# ['NY', 'CA', 'IL', 'OH', 'MI', 'TX', 'PA', 'FL']

# %%
state_target_year = inputs["State Target Year"]
states_tz =  inputs["State Timezone"]
state_heater_year =  inputs["State Heater Year"]
state_water_year =  inputs["State Water Year"]
state_heater_AR =  inputs["State Heater AR"]
state_water_AR =  inputs["State Water AR"]

# %% [markdown]
# ## Import NREL Stock data and format (for all states and building types)
# If not cached it will pull from NREL API

# %%
api = API()
data = {}

for state in com_states:
    print(state)
    
    for btype in BUILDING_TYPES:
        filename = f"./nrel_data_2023/{sector}_{state}_{btype}.csv"
        if not os.path.exists(filename):
        
            # Download data
            df = api.get_data_comstock_by_state(state, btype)
            df = format_columns_df(df)

            # Save locally
            try:
                df.to_csv(filename)
            except OSError:
                os.mkdir("./nrel_data_2023")
                df.to_csv(filename)
            

        # Load cached data
        df = pd.read_csv(f"./nrel_data_2023/{sector}_{state}_{btype}.csv")
        df["Datetime"] = Timeseries.make_datetime(df["timestamp"])
        df = df.drop("timestamp", axis=1)
        df.sort_values("Datetime", inplace=True, ascending=True)
        df.set_index("Datetime", inplace=True, drop=True)
        data[f"{state}_{btype}"] = df
        if 'Propane Heating' in df.columns or 'Fuel Oil Heating' in df.columns:
            print(state, btype, df.columns)
# Out:
# NY
# CA
# IL
# OH
# MI
# TX
# PA
# FL

# %% [markdown]
# ## Start loop to get new supply for each state and building types

# %%
results_comm = {} # Structure: results_comm[str_study_year][state][btype]

# %%
for study_year in year_range:
    print(study_year)
    str_study_year = str(study_year)
    results_comm[str_study_year] = {}
    
    for state in com_states:
        print(state)
        results_comm[str_study_year][state] = {}
        
        # Set params for each state
        # Target year
        target_year = state_target_year[state]
        # Peak adoption year per end use
        heater_year, water_year = state_heater_year[state], state_water_year[state]
        # Adoption rate per end use
        heater_AR, water_AR = state_heater_AR[state], state_water_AR[state]


        aggregation = "avg" # "avg" or "peak_day"
        month_start = 1
        month_end = 12
        day_type = None
        timezone = states_tz[state]
        

        for btype in BUILDING_TYPES:
            df = data[f"{state}_{btype}"]
            
           
           # 'Natural Gas Interior Equipment', 
           #  'Other Fuel Cooling',
           # 'Natural Gas Cooling',
           # 'Other Fuel Interior Equipment', ,
           # ],

            comstock_heating = df[['Other Fuel Heating', 'Natural Gas Heating']].sum(axis=1)
            comstock_water_heating = df[['Other Fuel Water Heating', 'Natural Gas Water Heating']].sum(axis=1)

            appliance = [comstock_heating, comstock_water_heating]

            initial_year = dt.datetime.now().year
            new_sup = np.zeros((100,4))
            final_val = np.zeros((100,4))
            X0 = [heater_year, water_year]
            K = [heater_AR, water_AR]


            # applying arithmetic or geometric growth rate to achieve electrification
            for i in range(len(appliance)):
                # Initial and target value
                initial_value = appliance[i].sum()
                target_value = 1

                # Calculate parameters
                L = target_value - initial_value
                x0 = X0[i]
                k = K[i]/100  # adjust this to suit your needs

                # Generate x values
                x = np.linspace(initial_year, target_year, 100)

                final_val[:,i] = sigmoid(x, L, k, x0) + initial_value
                new_sup[:,i] = -sigmoid(x, L, k, x0)
                
                # Plot sigmoid functions
                
#                 plt.plot(x, new_sup[:,0]/1e9, color='tab:blue', label = 'Space heater')
#                 plt.axvline(x=X0[0],ls=':', color='tab:blue', label='Peak adoption year - space heater')

#                 plt.plot(x, new_sup[:,1]/1e9, color='tab:orange', label = 'Water heater')
#                 plt.axvline(x=X0[1], ls=':', color='tab:orange', label='Peak adoption year - water heater')

#                 # plt.axvline(x=X0[0], color='b', ls=':', label='Peak Adoption Year')
#                 plt.ylabel('New Supply (billion kWh)')
#                 plt.xlabel('year')
#                 plt.title(f'{state} Sigmoid Adoption Rate for End-Uses Electrification')
#                 plt.legend(loc=2, prop={'size': 6})
#                 plt.grid()
#                 plt.show();


                # Calculating the new supply for a given year
                new_supply = comstock_heating*(1/(1+np.exp(-K[0]/100*(study_year - X0[0])))) + \
                comstock_water_heating*(1/(1+np.exp(-K[1]/100*(study_year - X0[1]))))

                df['New Supply'] = new_supply
                df['New Electricity Total'] = new_supply  + df["Electricity Total"]
                

            # Aggregation of loadshape per state 
            df_agg = Timeseries.timeseries_aggregate(df, aggregation, month_start, month_end, day_type)

            # Time zone adjusting
            if timezone != 'EST':
                if timezone == 'CST':
                    shift = -1 # hrs
                elif timezone == 'MST':
                    shift = -2 # hrs
                elif timezone == 'PST':
                    shift = -3 # hrs
                df_old_values = df_agg[:-shift]
                df_agg = df_agg.shift(periods=shift)
                df_agg[shift:] = df_old_values.values

            df_agg['hour'] = pd.date_range("00:00", "23:45", freq="1H").hour
            # df_agg['minute'] = pd.date_range("00:00", "23:45", freq="1").minute
            df_agg["Load Growth"] = (df_agg["New Supply"]/df_agg["Electricity Total"]).values
            
            
             # Save total new supply added
            df_agg['Total Energy Added'] = df['New Supply'].values.sum()

            results_comm[str_study_year][state][btype] = df_agg
# Out:
# 2023
# NY
# CA
# IL
# OH
# MI
# TX
# PA
# FL
# 2024
# NY
# CA
# IL
# OH
# MI
# TX
# PA
# FL
# 2025
# NY
# CA
# IL
# OH
# MI
# TX
# PA
# FL
# 2026
# NY
# CA
# IL
# OH
# MI
# TX
# PA
# FL
# 2027
# NY
# CA
# IL
# OH
# MI
# TX
# PA
# FL
# 2028
# NY
# CA
# IL
# OH
# MI
# TX
# PA
# FL
# 2029
# NY
# CA
# IL
# OH
# MI
# TX
# PA
# FL
# 2030
# NY
# CA
# IL
# OH
# MI
# TX
# PA
# FL
# 2031
# NY
# CA
# IL
# OH
# MI
# TX
# PA
# FL
# 2032
# NY
# CA
# IL
# OH
# MI
# TX
# PA
# FL
# 2033
# NY
# CA
# IL
# OH
# MI
# TX
# PA
# FL
# 2034
# NY
# CA
# IL
# OH
# MI
# TX
# PA
# FL
# 2035
# NY
# CA
# IL
# OH
# MI
# TX
# PA
# FL
# 2036
# NY
# CA
# IL
# OH
# MI
# TX
# PA
# FL
# 2037
# NY
# CA
# IL
# OH
# MI
# TX
# PA
# FL
# 2038
# NY
# CA
# IL
# OH
# MI
# TX
# PA
# FL
# 2039
# NY
# CA
# IL
# OH
# MI
# TX
# PA
# FL
# 2040
# NY
# CA
# IL
# OH
# MI
# TX
# PA
# FL
# 2041
# NY
# CA
# IL
# OH
# MI
# TX
# PA
# FL
# 2042
# NY
# CA
# IL
# OH
# MI
# TX
# PA
# FL
# 2043
# NY
# CA
# IL
# OH
# MI
# TX
# PA
# FL
# 2044
# NY
# CA
# IL
# OH
# MI
# TX
# PA
# FL
# 2045
# NY
# CA
# IL
# OH
# MI
# TX
# PA
# FL
# 2046
# NY
# CA
# IL
# OH
# MI
# TX
# PA
# FL
# 2047
# NY
# CA
# IL
# OH
# MI
# TX
# PA
# FL
# 2048
# NY
# CA
# IL
# OH
# MI
# TX
# PA
# FL
# 2049
# NY
# CA
# IL
# OH
# MI
# TX
# PA
# FL
# 2050
# NY
# CA
# IL
# OH
# MI
# TX
# PA
# FL

# %% [markdown]
# ## Get peaks and peak times of the sum of the building types for each state

# %%
for study_year in year_range:
    print(study_year)
    str_study_year = str(study_year)
    
    for state in com_states:
        print(state)
        
        # Sums over state btype
        state_elec_total = pd.Series([0]*24, name="State Electricity Total")
        state_new_elec_total = pd.Series([0]*24, name="State New Electricity Total")
        state_new_supply = pd.Series([0]*24, name="State New Supply")
        state_total_energy_added = pd.Series([0]*24, name="State Total Energy Added")

        
        for btype in BUILDING_TYPES:
            
            state_elec_total += results_comm[str_study_year][state][btype]["Electricity Total"]     
            state_new_elec_total += results_comm[str_study_year][state][btype]["New Electricity Total"] 
            state_new_supply += results_comm[str_study_year][state][btype]["New Supply"]
            state_total_energy_added += results_comm[str_study_year][state][btype]["Total Energy Added"]
        
        
        # Df of sums over state
        state_sums_df = pd.concat([df_agg["hour"], state_elec_total, state_new_elec_total, state_new_supply, state_total_energy_added], axis=1)
        state_sums_df["State Load Growth"] = (state_sums_df["State New Supply"]/state_sums_df["State Electricity Total"])

        results_comm[str_study_year][state]["Sums"] = state_sums_df
        
        # Loadshape analysis to get peak times 
        peak, peak_time, new_peak, new_peak_time, load_growth, supply_peak, supply_peak_time = loadshape_analysis(state_sums_df)        
        results_comm[str_study_year][state]["Total Energy Supply Added from Current Energy Consumption"] = state_sums_df["State Total Energy Added"][0]/1e9
        results_comm[str_study_year][state]["Total Energy Supply Added from Current Energy Consumption - units"] = "TWh"
        results_comm[str_study_year][state]["Current Peak"]  = np.round(peak[0],0)
        results_comm[str_study_year][state]["Current Peak - units"] = "MW"
        results_comm[str_study_year][state]["Current Peak - time"] = peak_time
        results_comm[str_study_year][state]["New Peak"]  = np.round(new_peak[0],0)
        results_comm[str_study_year][state]["New Peak - units"] = "MW"
        results_comm[str_study_year][state]["New Peak - time"] = new_peak_time
        results_comm[str_study_year][state]["New Supply"]  = np.round(supply_peak[0],0)
        results_comm[str_study_year][state]["New Supply - units"] = "MW"
        results_comm[str_study_year][state]["New Supply - time"] = supply_peak_time
        results_comm[str_study_year][state]["Load Growth"]  = np.round(load_growth,2)
        results_comm[str_study_year][state]["Load Growth - units"] = "%"
        results_comm[str_study_year][state]["Load Growth - time"] = new_peak_time

        
#         # Plot sum over btype for each state
#         t = state_sums_df["hour"]

#         # Plotting elec
#         plt.plot(t, state_sums_df['State Electricity Total']/1e3 *(60/15), label = 'Current Loadshape')
#         plt.plot(t, state_sums_df['State New Electricity Total']/1e3 *(60/15), label = 'Loadshape with Electrification')
#         #plt.ylim(bottom=0)
#         plt.xlabel('Hour (hr)')
#         plt.ylabel('Power demand (MW)')
#         plt.xticks([0,6,12,18,24])
#         plt.title(str(state) + ' ' + ' Loadshape with Electrification - ' + str(aggregation) + ' over year ' + str(study_year))
#         plt.grid(alpha=0.3)
#         plt.legend()
#         plt.show()

        print(f"Total Energy supply added from current energy consumption = {np.round(state_sums_df['State Total Energy Added'][0]/1e9, 1)}  TWh") 
        print(f"Current Peak {np.round(peak[0],0)} MW, time: {peak_time}")
        print(f"New Peak     {np.round(new_peak[0],0)} MW, time: {new_peak_time}")
        print(f"New Supply   {np.round(supply_peak[0],0)} MW, time: {supply_peak_time}")
        print(f"Load Growth  {np.round(load_growth,2)} %, time: {new_peak_time}")
# Out:
# 2023
# NY
# Total Energy supply added from current energy consumption = 0.4  TWh
# Current Peak 8181.0 MW, time: 11:00
# New Peak     8236.0 MW, time: 11:00
# New Supply   68.0 MW, time: 7:00
# Load Growth  0.68 %, time: 11:00
# CA
# Total Energy supply added from current energy consumption = 0.5  TWh
# Current Peak 17267.0 MW, time: 12:00
# New Peak     17300.0 MW, time: 12:00
# New Supply   82.0 MW, time: 6:00
# Load Growth  0.2 %, time: 12:00
# IL
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 5403.0 MW, time: 12:00
# New Peak     5406.0 MW, time: 12:00
# New Supply   3.0 MW, time: 7:00
# Load Growth  0.04 %, time: 12:00
# OH
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 5586.0 MW, time: 11:00
# New Peak     5588.0 MW, time: 11:00
# New Supply   3.0 MW, time: 7:00
# Load Growth  0.04 %, time: 11:00
# MI
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 3529.0 MW, time: 12:00
# New Peak     3531.0 MW, time: 12:00
# New Supply   3.0 MW, time: 7:00
# Load Growth  0.06 %, time: 12:00
# TX
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 15412.0 MW, time: 12:00
# New Peak     15414.0 MW, time: 12:00
# New Supply   2.0 MW, time: 7:00
# Load Growth  0.01 %, time: 12:00
# PA
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 5709.0 MW, time: 11:00
# New Peak     5710.0 MW, time: 11:00
# New Supply   2.0 MW, time: 7:00
# Load Growth  0.03 %, time: 11:00
# FL
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 13360.0 MW, time: 12:00
# New Peak     13360.0 MW, time: 12:00
# New Supply   1.0 MW, time: 10:00
# Load Growth  0.01 %, time: 12:00
# 2024
# NY
# Total Energy supply added from current energy consumption = 0.7  TWh
# Current Peak 8181.0 MW, time: 11:00
# New Peak     8271.0 MW, time: 11:00
# New Supply   109.0 MW, time: 7:00
# Load Growth  1.1 %, time: 11:00
# CA
# Total Energy supply added from current energy consumption = 0.8  TWh
# Current Peak 17267.0 MW, time: 12:00
# New Peak     17321.0 MW, time: 12:00
# New Supply   133.0 MW, time: 6:00
# Load Growth  0.32 %, time: 12:00
# IL
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 5403.0 MW, time: 12:00
# New Peak     5407.0 MW, time: 12:00
# New Supply   6.0 MW, time: 7:00
# Load Growth  0.07 %, time: 12:00
# OH
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 5586.0 MW, time: 11:00
# New Peak     5590.0 MW, time: 11:00
# New Supply   5.0 MW, time: 7:00
# Load Growth  0.07 %, time: 11:00
# MI
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 3529.0 MW, time: 12:00
# New Peak     3533.0 MW, time: 12:00
# New Supply   5.0 MW, time: 7:00
# Load Growth  0.1 %, time: 12:00
# TX
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 15412.0 MW, time: 12:00
# New Peak     15414.0 MW, time: 12:00
# New Supply   3.0 MW, time: 7:00
# Load Growth  0.01 %, time: 12:00
# PA
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 5709.0 MW, time: 11:00
# New Peak     5711.0 MW, time: 11:00
# New Supply   3.0 MW, time: 7:00
# Load Growth  0.05 %, time: 11:00
# FL
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 13360.0 MW, time: 12:00
# New Peak     13361.0 MW, time: 12:00
# New Supply   1.0 MW, time: 10:00
# Load Growth  0.01 %, time: 12:00
# 2025
# NY
# Total Energy supply added from current energy consumption = 1.1  TWh
# Current Peak 8181.0 MW, time: 11:00
# New Peak     8325.0 MW, time: 11:00
# New Supply   175.0 MW, time: 7:00
# Load Growth  1.76 %, time: 11:00
# CA
# Total Energy supply added from current energy consumption = 1.3  TWh
# Current Peak 17267.0 MW, time: 12:00
# New Peak     17354.0 MW, time: 12:00
# New Supply   213.0 MW, time: 6:00
# Load Growth  0.51 %, time: 12:00
# IL
# Total Energy supply added from current energy consumption = 0.1  TWh
# Current Peak 5403.0 MW, time: 12:00
# New Peak     5410.0 MW, time: 12:00
# New Supply   9.0 MW, time: 7:00
# Load Growth  0.12 %, time: 12:00
# OH
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 5586.0 MW, time: 11:00
# New Peak     5592.0 MW, time: 11:00
# New Supply   8.0 MW, time: 7:00
# Load Growth  0.11 %, time: 11:00
# MI
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 3529.0 MW, time: 12:00
# New Peak     3535.0 MW, time: 12:00
# New Supply   8.0 MW, time: 7:00
# Load Growth  0.16 %, time: 12:00
# TX
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 15412.0 MW, time: 12:00
# New Peak     15416.0 MW, time: 12:00
# New Supply   5.0 MW, time: 7:00
# Load Growth  0.02 %, time: 12:00
# PA
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 5709.0 MW, time: 11:00
# New Peak     5713.0 MW, time: 11:00
# New Supply   5.0 MW, time: 7:00
# Load Growth  0.07 %, time: 11:00
# FL
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 13360.0 MW, time: 12:00
# New Peak     13361.0 MW, time: 12:00
# New Supply   2.0 MW, time: 10:00
# Load Growth  0.01 %, time: 12:00
# 2026
# NY
# Total Energy supply added from current energy consumption = 1.8  TWh
# Current Peak 8181.0 MW, time: 11:00
# New Peak     8407.0 MW, time: 11:00
# New Supply   275.0 MW, time: 7:00
# Load Growth  2.77 %, time: 11:00
# CA
# Total Energy supply added from current energy consumption = 2.0  TWh
# Current Peak 17267.0 MW, time: 12:00
# New Peak     17405.0 MW, time: 12:00
# New Supply   334.0 MW, time: 6:00
# Load Growth  0.8 %, time: 12:00
# IL
# Total Energy supply added from current energy consumption = 0.1  TWh
# Current Peak 5403.0 MW, time: 12:00
# New Peak     5414.0 MW, time: 12:00
# New Supply   15.0 MW, time: 7:00
# Load Growth  0.2 %, time: 12:00
# OH
# Total Energy supply added from current energy consumption = 0.1  TWh
# Current Peak 5586.0 MW, time: 11:00
# New Peak     5596.0 MW, time: 11:00
# New Supply   13.0 MW, time: 7:00
# Load Growth  0.19 %, time: 11:00
# MI
# Total Energy supply added from current energy consumption = 0.1  TWh
# Current Peak 3529.0 MW, time: 12:00
# New Peak     3538.0 MW, time: 12:00
# New Supply   13.0 MW, time: 7:00
# Load Growth  0.27 %, time: 12:00
# TX
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 15412.0 MW, time: 12:00
# New Peak     15418.0 MW, time: 12:00
# New Supply   8.0 MW, time: 7:00
# Load Growth  0.04 %, time: 12:00
# PA
# Total Energy supply added from current energy consumption = 0.1  TWh
# Current Peak 5709.0 MW, time: 11:00
# New Peak     5716.0 MW, time: 11:00
# New Supply   9.0 MW, time: 7:00
# Load Growth  0.12 %, time: 11:00
# FL
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 13360.0 MW, time: 12:00
# New Peak     13363.0 MW, time: 12:00
# New Supply   3.0 MW, time: 10:00
# Load Growth  0.02 %, time: 12:00
# 2027
# NY
# Total Energy supply added from current energy consumption = 2.7  TWh
# Current Peak 8181.0 MW, time: 11:00
# New Peak     8527.0 MW, time: 11:00
# New Supply   421.0 MW, time: 7:00
# Load Growth  4.23 %, time: 11:00
# CA
# Total Energy supply added from current energy consumption = 3.0  TWh
# Current Peak 17267.0 MW, time: 12:00
# New Peak     17478.0 MW, time: 12:00
# New Supply   511.0 MW, time: 6:00
# Load Growth  1.22 %, time: 12:00
# IL
# Total Energy supply added from current energy consumption = 0.2  TWh
# Current Peak 5403.0 MW, time: 12:00
# New Peak     5421.0 MW, time: 11:00
# New Supply   25.0 MW, time: 7:00
# Load Growth  0.35 %, time: 11:00
# OH
# Total Energy supply added from current energy consumption = 0.1  TWh
# Current Peak 5586.0 MW, time: 11:00
# New Peak     5603.0 MW, time: 11:00
# New Supply   22.0 MW, time: 7:00
# Load Growth  0.3 %, time: 11:00
# MI
# Total Energy supply added from current energy consumption = 0.1  TWh
# Current Peak 3529.0 MW, time: 12:00
# New Peak     3544.0 MW, time: 12:00
# New Supply   22.0 MW, time: 7:00
# Load Growth  0.44 %, time: 12:00
# TX
# Total Energy supply added from current energy consumption = 0.1  TWh
# Current Peak 15412.0 MW, time: 12:00
# New Peak     15422.0 MW, time: 12:00
# New Supply   14.0 MW, time: 7:00
# Load Growth  0.06 %, time: 12:00
# PA
# Total Energy supply added from current energy consumption = 0.1  TWh
# Current Peak 5709.0 MW, time: 11:00
# New Peak     5720.0 MW, time: 11:00
# New Supply   14.0 MW, time: 7:00
# Load Growth  0.2 %, time: 11:00
# FL
# Total Energy supply added from current energy consumption = 0.0  TWh
# Current Peak 13360.0 MW, time: 12:00
# New Peak     13365.0 MW, time: 12:00
# New Supply   5.0 MW, time: 10:00
# Load Growth  0.04 %, time: 12:00
# 2028
# NY
# Total Energy supply added from current energy consumption = 4.0  TWh
# Current Peak 8181.0 MW, time: 11:00
# New Peak     8691.0 MW, time: 11:00
# New Supply   621.0 MW, time: 7:00
# Load Growth  6.24 %, time: 11:00
# CA
# Total Energy supply added from current energy consumption = 4.5  TWh
# Current Peak 17267.0 MW, time: 12:00
# New Peak     17578.0 MW, time: 12:00
# New Supply   754.0 MW, time: 6:00
# Load Growth  1.8 %, time: 12:00
# IL
# Total Energy supply added from current energy consumption = 0.3  TWh
# Current Peak 5403.0 MW, time: 12:00
# New Peak     5433.0 MW, time: 11:00
# New Supply   41.0 MW, time: 7:00
# Load Growth  0.57 %, time: 11:00
# OH
# Total Energy supply added from current energy consumption = 0.2  TWh
# Current Peak 5586.0 MW, time: 11:00
# New Peak     5614.0 MW, time: 11:00
# New Supply   35.0 MW, time: 7:00
# Load Growth  0.5 %, time: 11:00
# MI
# Total Energy supply added from current energy consumption = 0.2  TWh
# Current Peak 3529.0 MW, time: 12:00
# New Peak     3554.0 MW, time: 12:00
# New Supply   35.0 MW, time: 7:00
# Load Growth  0.72 %, time: 12:00
# TX
# Total Energy supply added from current energy consumption = 0.1  TWh
# Current Peak 15412.0 MW, time: 12:00
# New Peak     15428.0 MW, time: 12:00
# New Supply   22.0 MW, time: 7:00
# Load Growth  0.1 %, time: 12:00
# PA
# Total Energy supply added from current energy consumption = 0.1  TWh
# Current Peak 5709.0 MW, time: 11:00
# New Peak     5728.0 MW, time: 11:00
# New Supply   24.0 MW, time: 7:00
# Load Growth  0.33 %, time: 11:00
# FL
# Total Energy supply added from current energy consumption = 0.1  TWh
# Current Peak 13360.0 MW, time: 12:00
# New Peak     13368.0 MW, time: 12:00
# New Supply   8.0 MW, time: 10:00
# Load Growth  0.06 %, time: 12:00
# 2029
# NY
# Total Energy supply added from current energy consumption = 5.7  TWh
# Current Peak 8181.0 MW, time: 11:00
# New Peak     8897.0 MW, time: 11:00
# New Supply   872.0 MW, time: 7:00
# Load Growth  8.76 %, time: 11:00
# CA
# Total Energy supply added from current energy consumption = 6.3  TWh
# Current Peak 17267.0 MW, time: 12:00
# New Peak     17704.0 MW, time: 12:00
# New Supply   1059.0 MW, time: 6:00
# Load Growth  2.53 %, time: 12:00
# IL
# Total Energy supply added from current energy consumption = 0.4  TWh
# Current Peak 5403.0 MW, time: 12:00
# New Peak     5453.0 MW, time: 11:00
# New Supply   66.0 MW, time: 7:00
# Load Growth  0.94 %, time: 11:00
# OH
# Total Energy supply added from current energy consumption = 0.4  TWh
# Current Peak 5586.0 MW, time: 11:00
# New Peak     5631.0 MW, time: 11:00
# New Supply   58.0 MW, time: 7:00
# Load Growth  0.81 %, time: 11:00
# MI
# Total Energy supply added from current energy consumption = 0.4  TWh
# Current Peak 3529.0 MW, time: 12:00
# New Peak     3570.0 MW, time: 12:00
# New Supply   58.0 MW, time: 7:00
# Load Growth  1.17 %, time: 12:00
# TX
# Total Energy supply added from current energy consumption = 0.2  TWh
# Current Peak 15412.0 MW, time: 12:00
# New Peak     15437.0 MW, time: 12:00
# New Supply   37.0 MW, time: 7:00
# Load Growth  0.16 %, time: 12:00
# PA
# Total Energy supply added from current energy consumption = 0.2  TWh
# Current Peak 5709.0 MW, time: 11:00
# New Peak     5740.0 MW, time: 11:00
# New Supply   39.0 MW, time: 7:00
# Load Growth  0.54 %, time: 11:00
# FL
# Total Energy supply added from current energy consumption = 0.1  TWh
# Current Peak 13360.0 MW, time: 12:00
# New Peak     13373.0 MW, time: 12:00
# New Supply   14.0 MW, time: 10:00
# Load Growth  0.1 %, time: 12:00
# 2030
# NY
# Total Energy supply added from current energy consumption = 7.5  TWh
# Current Peak 8181.0 MW, time: 11:00
# New Peak     9130.0 MW, time: 11:00
# New Supply   1154.0 MW, time: 7:00
# Load Growth  11.6 %, time: 11:00
# CA
# Total Energy supply added from current energy consumption = 8.3  TWh
# Current Peak 17267.0 MW, time: 12:00
# New Peak     17845.0 MW, time: 12:00
# New Supply   1402.0 MW, time: 6:00
# Load Growth  3.35 %, time: 12:00
# IL
# Total Energy supply added from current energy consumption = 0.7  TWh
# Current Peak 5403.0 MW, time: 12:00
# New Peak     5484.0 MW, time: 11:00
# New Supply   107.0 MW, time: 7:00
# Load Growth  1.51 %, time: 11:00
# OH
# Total Energy supply added from current energy consumption = 0.6  TWh
# Current Peak 5586.0 MW, time: 11:00
# New Peak     5659.0 MW, time: 11:00
# New Supply   93.0 MW, time: 7:00
# Load Growth  1.32 %, time: 11:00
# MI
# Total Energy supply added from current energy consumption = 0.6  TWh
# Current Peak 3529.0 MW, time: 12:00
# New Peak     3596.0 MW, time: 12:00
# New Supply   93.0 MW, time: 7:00
# Load Growth  1.89 %, time: 12:00
# TX
# Total Energy supply added from current energy consumption = 0.3  TWh
# Current Peak 15412.0 MW, time: 12:00
# New Peak     15453.0 MW, time: 12:00
# New Supply   59.0 MW, time: 7:00
# Load Growth  0.26 %, time: 12:00
# PA
# Total Energy supply added from current energy consumption = 0.4  TWh
# Current Peak 5709.0 MW, time: 11:00
# New Peak     5759.0 MW, time: 11:00
# New Supply   62.0 MW, time: 7:00
# Load Growth  0.87 %, time: 11:00
# FL
# Total Energy supply added from current energy consumption = 0.1  TWh
# Current Peak 13360.0 MW, time: 12:00
# New Peak     13381.0 MW, time: 12:00
# New Supply   22.0 MW, time: 10:00
# Load Growth  0.16 %, time: 12:00
# 2031
# NY
# Total Energy supply added from current energy consumption = 9.4  TWh
# Current Peak 8181.0 MW, time: 11:00
# New Peak     9362.0 MW, time: 11:00
# New Supply   1437.0 MW, time: 7:00
# Load Growth  14.44 %, time: 11:00
# CA
# Total Energy supply added from current energy consumption = 10.4  TWh
# Current Peak 17267.0 MW, time: 12:00
# New Peak     17987.0 MW, time: 12:00
# New Supply   1745.0 MW, time: 6:00
# Load Growth  4.17 %, time: 12:00
# IL
# Total Energy supply added from current energy consumption = 1.1  TWh
# Current Peak 5403.0 MW, time: 12:00
# New Peak     5533.0 MW, time: 11:00
# New Supply   172.0 MW, time: 7:00
# Load Growth  2.42 %, time: 11:00
# OH
# Total Energy supply added from current energy consumption = 0.9  TWh
# Current Peak 5586.0 MW, time: 11:00
# New Peak     5704.0 MW, time: 11:00
# New Supply   149.0 MW, time: 7:00
# Load Growth  2.11 %, time: 11:00
# MI
# Total Energy supply added from current energy consumption = 0.9  TWh
# Current Peak 3529.0 MW, time: 12:00
# New Peak     3636.0 MW, time: 11:00
# New Supply   149.0 MW, time: 7:00
# Load Growth  3.28 %, time: 11:00
# TX
# Total Energy supply added from current energy consumption = 0.5  TWh
# Current Peak 15412.0 MW, time: 12:00
# New Peak     15477.0 MW, time: 12:00
# New Supply   95.0 MW, time: 7:00
# Load Growth  0.42 %, time: 12:00
# PA
# Total Energy supply added from current energy consumption = 0.6  TWh
# Current Peak 5709.0 MW, time: 11:00
# New Peak     5788.0 MW, time: 11:00
# New Supply   100.0 MW, time: 7:00
# Load Growth  1.39 %, time: 11:00
# FL
# Total Energy supply added from current energy consumption = 0.2  TWh
# Current Peak 13360.0 MW, time: 12:00
# New Peak     13394.0 MW, time: 12:00
# New Supply   35.0 MW, time: 10:00
# Load Growth  0.26 %, time: 12:00
# 2032
# NY
# Total Energy supply added from current energy consumption = 11.0  TWh
# Current Peak 8181.0 MW, time: 11:00
# New Peak     9568.0 MW, time: 11:00
# New Supply   1688.0 MW, time: 7:00
# Load Growth  16.96 %, time: 11:00
# CA
# Total Energy supply added from current energy consumption = 12.2  TWh
# Current Peak 17267.0 MW, time: 12:00
# New Peak     18113.0 MW, time: 12:00
# New Supply   2050.0 MW, time: 6:00
# Load Growth  4.9 %, time: 12:00
# IL
# Total Energy supply added from current energy consumption = 1.7  TWh
# Current Peak 5403.0 MW, time: 12:00
# New Peak     5607.0 MW, time: 11:00
# New Supply   270.0 MW, time: 7:00
# Load Growth  3.8 %, time: 11:00
# OH
# Total Energy supply added from current energy consumption = 1.4  TWh
# Current Peak 5586.0 MW, time: 11:00
# New Peak     5771.0 MW, time: 11:00
# New Supply   234.0 MW, time: 7:00
# Load Growth  3.31 %, time: 11:00
# MI
# Total Energy supply added from current energy consumption = 1.4  TWh
# Current Peak 3529.0 MW, time: 12:00
# New Peak     3702.0 MW, time: 11:00
# New Supply   235.0 MW, time: 7:00
# Load Growth  5.15 %, time: 11:00
# TX
# Total Energy supply added from current energy consumption = 0.8  TWh
# Current Peak 15412.0 MW, time: 12:00
# New Peak     15514.0 MW, time: 12:00
# New Supply   149.0 MW, time: 7:00
# Load Growth  0.66 %, time: 12:00
# PA
# Total Energy supply added from current energy consumption = 1.0  TWh
# Current Peak 5709.0 MW, time: 11:00
# New Peak     5834.0 MW, time: 11:00
# New Supply   157.0 MW, time: 7:00
# Load Growth  2.19 %, time: 11:00
# FL
# Total Energy supply added from current energy consumption = 0.3  TWh
# Current Peak 13360.0 MW, time: 12:00
# New Peak     13414.0 MW, time: 12:00
# New Supply   55.0 MW, time: 10:00
# Load Growth  0.4 %, time: 12:00
# 2033
# NY
# Total Energy supply added from current energy consumption = 12.3  TWh
# Current Peak 8181.0 MW, time: 11:00
# New Peak     9732.0 MW, time: 11:00
# New Supply   1887.0 MW, time: 7:00
# Load Growth  18.97 %, time: 11:00
# CA
# Total Energy supply added from current energy consumption = 13.7  TWh
# Current Peak 17267.0 MW, time: 12:00
# New Peak     18213.0 MW, time: 12:00
# New Supply   2292.0 MW, time: 6:00
# Load Growth  5.48 %, time: 12:00
# IL
# Total Energy supply added from current energy consumption = 2.6  TWh
# Current Peak 5403.0 MW, time: 12:00
# New Peak     5716.0 MW, time: 11:00
# New Supply   413.0 MW, time: 7:00
# Load Growth  5.82 %, time: 11:00
# OH
# Total Energy supply added from current energy consumption = 2.2  TWh
# Current Peak 5586.0 MW, time: 11:00
# New Peak     5869.0 MW, time: 11:00
# New Supply   359.0 MW, time: 7:00
# Load Growth  5.06 %, time: 11:00
# MI
# Total Energy supply added from current energy consumption = 2.2  TWh
# Current Peak 3529.0 MW, time: 12:00
# New Peak     3798.0 MW, time: 11:00
# New Supply   359.0 MW, time: 7:00
# Load Growth  7.88 %, time: 11:00
# TX
# Total Energy supply added from current energy consumption = 1.3  TWh
# Current Peak 15412.0 MW, time: 12:00
# New Peak     15568.0 MW, time: 12:00
# New Supply   227.0 MW, time: 7:00
# Load Growth  1.01 %, time: 12:00
# PA
# Total Energy supply added from current energy consumption = 1.5  TWh
# Current Peak 5709.0 MW, time: 11:00
# New Peak     5900.0 MW, time: 11:00
# New Supply   240.0 MW, time: 7:00
# Load Growth  3.35 %, time: 11:00
# FL
# Total Energy supply added from current energy consumption = 0.5  TWh
# Current Peak 13360.0 MW, time: 12:00
# New Peak     13442.0 MW, time: 12:00
# New Supply   84.0 MW, time: 10:00
# Load Growth  0.62 %, time: 12:00
# 2034
# NY
# Total Energy supply added from current energy consumption = 13.2  TWh
# Current Peak 8181.0 MW, time: 11:00
# New Peak     9854.0 MW, time: 10:00
# New Supply   2033.0 MW, time: 7:00
# Load Growth  22.13 %, time: 10:00
# CA
# Total Energy supply added from current energy consumption = 14.7  TWh
# Current Peak 17267.0 MW, time: 12:00
# New Peak     18286.0 MW, time: 12:00
# New Supply   2470.0 MW, time: 6:00
# Load Growth  5.9 %, time: 12:00
# IL
# Total Energy supply added from current energy consumption = 3.8  TWh
# Current Peak 5403.0 MW, time: 12:00
# New Peak     5866.0 MW, time: 11:00
# New Supply   609.0 MW, time: 7:00
# Load Growth  8.58 %, time: 11:00
# OH
# Total Energy supply added from current energy consumption = 3.3  TWh
# Current Peak 5586.0 MW, time: 11:00
# New Peak     6003.0 MW, time: 11:00
# New Supply   529.0 MW, time: 7:00
# Load Growth  7.47 %, time: 11:00
# MI
# Total Energy supply added from current energy consumption = 3.2  TWh
# Current Peak 3529.0 MW, time: 12:00
# New Peak     3930.0 MW, time: 11:00
# New Supply   530.0 MW, time: 7:00
# Load Growth  11.62 %, time: 11:00
# TX
# Total Energy supply added from current energy consumption = 1.9  TWh
# Current Peak 15412.0 MW, time: 12:00
# New Peak     15641.0 MW, time: 12:00
# New Supply   335.0 MW, time: 7:00
# Load Growth  1.48 %, time: 12:00
# PA
# Total Energy supply added from current energy consumption = 2.2  TWh
# Current Peak 5709.0 MW, time: 11:00
# New Peak     5991.0 MW, time: 11:00
# New Supply   353.0 MW, time: 7:00
# Load Growth  4.94 %, time: 11:00
# FL
# Total Energy supply added from current energy consumption = 0.8  TWh
# Current Peak 13360.0 MW, time: 12:00
# New Peak     13481.0 MW, time: 12:00
# New Supply   124.0 MW, time: 10:00
# Load Growth  0.91 %, time: 12:00
# 2035
# NY
# Total Energy supply added from current energy consumption = 13.9  TWh
# Current Peak 8181.0 MW, time: 11:00
# New Peak     9942.0 MW, time: 10:00
# New Supply   2133.0 MW, time: 7:00
# Load Growth  23.22 %, time: 10:00
# CA
# Total Energy supply added from current energy consumption = 15.4  TWh
# Current Peak 17267.0 MW, time: 12:00
# New Peak     18336.0 MW, time: 12:00
# New Supply   2591.0 MW, time: 6:00
# Load Growth  6.2 %, time: 12:00
# IL
# Total Energy supply added from current energy consumption = 5.3  TWh
# Current Peak 5403.0 MW, time: 12:00
# New Peak     6053.0 MW, time: 11:00
# New Supply   854.0 MW, time: 7:00
# Load Growth  12.04 %, time: 11:00
# OH
# Total Energy supply added from current energy consumption = 4.6  TWh
# Current Peak 5586.0 MW, time: 11:00
# New Peak     6171.0 MW, time: 11:00
# New Supply   742.0 MW, time: 7:00
# Load Growth  10.48 %, time: 11:00
# MI
# Total Energy supply added from current energy consumption = 4.5  TWh
# Current Peak 3529.0 MW, time: 12:00
# New Peak     4095.0 MW, time: 11:00
# New Supply   743.0 MW, time: 7:00
# Load Growth  16.31 %, time: 11:00
# TX
# Total Energy supply added from current energy consumption = 2.7  TWh
# Current Peak 15412.0 MW, time: 12:00
# New Peak     15734.0 MW, time: 12:00
# New Supply   471.0 MW, time: 7:00
# Load Growth  2.08 %, time: 12:00
# PA
# Total Energy supply added from current energy consumption = 3.1  TWh
# Current Peak 5709.0 MW, time: 11:00
# New Peak     6105.0 MW, time: 11:00
# New Supply   496.0 MW, time: 7:00
# Load Growth  6.94 %, time: 11:00
# FL
# Total Energy supply added from current energy consumption = 1.1  TWh
# Current Peak 13360.0 MW, time: 12:00
# New Peak     13531.0 MW, time: 12:00
# New Supply   174.0 MW, time: 10:00
# Load Growth  1.28 %, time: 12:00
# 2036
# NY
# Total Energy supply added from current energy consumption = 14.3  TWh
# Current Peak 8181.0 MW, time: 11:00
# New Peak     9999.0 MW, time: 10:00
# New Supply   2199.0 MW, time: 7:00
# Load Growth  23.94 %, time: 10:00
# CA
# Total Energy supply added from current energy consumption = 15.9  TWh
# Current Peak 17267.0 MW, time: 12:00
# New Peak     18369.0 MW, time: 12:00
# New Supply   2671.0 MW, time: 6:00
# Load Growth  6.39 %, time: 12:00
# IL
# Total Energy supply added from current energy consumption = 7.1  TWh
# Current Peak 5403.0 MW, time: 12:00
# New Peak     6264.0 MW, time: 11:00
# New Supply   1132.0 MW, time: 7:00
# Load Growth  15.95 %, time: 11:00
# OH
# Total Energy supply added from current energy consumption = 6.0  TWh
# Current Peak 5586.0 MW, time: 11:00
# New Peak     6361.0 MW, time: 11:00
# New Supply   983.0 MW, time: 7:00
# Load Growth  13.88 %, time: 11:00
# MI
# Total Energy supply added from current energy consumption = 6.0  TWh
# Current Peak 3529.0 MW, time: 12:00
# New Peak     4281.0 MW, time: 11:00
# New Supply   984.0 MW, time: 7:00
# Load Growth  21.6 %, time: 11:00
# TX
# Total Energy supply added from current energy consumption = 3.5  TWh
# Current Peak 15412.0 MW, time: 12:00
# New Peak     15838.0 MW, time: 12:00
# New Supply   623.0 MW, time: 7:00
# Load Growth  2.76 %, time: 12:00
# PA
# Total Energy supply added from current energy consumption = 4.1  TWh
# Current Peak 5709.0 MW, time: 11:00
# New Peak     6233.0 MW, time: 11:00
# New Supply   657.0 MW, time: 7:00
# Load Growth  9.19 %, time: 11:00
# FL
# Total Energy supply added from current energy consumption = 1.4  TWh
# Current Peak 13360.0 MW, time: 12:00
# New Peak     13586.0 MW, time: 12:00
# New Supply   231.0 MW, time: 10:00
# Load Growth  1.7 %, time: 12:00
# 2037
# NY
# Total Energy supply added from current energy consumption = 14.6  TWh
# Current Peak 8181.0 MW, time: 11:00
# New Peak     10036.0 MW, time: 10:00
# New Supply   2241.0 MW, time: 7:00
# Load Growth  24.39 %, time: 10:00
# CA
# Total Energy supply added from current energy consumption = 16.2  TWh
# Current Peak 17267.0 MW, time: 12:00
# New Peak     18390.0 MW, time: 12:00
# New Supply   2722.0 MW, time: 6:00
# Load Growth  6.51 %, time: 12:00
# IL
# Total Energy supply added from current energy consumption = 8.8  TWh
# Current Peak 5403.0 MW, time: 12:00
# New Peak     6475.0 MW, time: 11:00
# New Supply   1409.0 MW, time: 7:00
# Load Growth  19.86 %, time: 11:00
# OH
# Total Energy supply added from current energy consumption = 7.5  TWh
# Current Peak 5586.0 MW, time: 11:00
# New Peak     6551.0 MW, time: 11:00
# New Supply   1223.0 MW, time: 7:00
# Load Growth  17.28 %, time: 11:00
# MI
# Total Energy supply added from current energy consumption = 7.4  TWh
# Current Peak 3529.0 MW, time: 12:00
# New Peak     4467.0 MW, time: 11:00
# New Supply   1226.0 MW, time: 7:00
# Load Growth  26.89 %, time: 11:00
# TX
# Total Energy supply added from current energy consumption = 4.4  TWh
# Current Peak 15412.0 MW, time: 12:00
# New Peak     15942.0 MW, time: 12:00
# New Supply   776.0 MW, time: 7:00
# Load Growth  3.44 %, time: 12:00
# PA
# Total Energy supply added from current energy consumption = 5.1  TWh
# Current Peak 5709.0 MW, time: 11:00
# New Peak     6362.0 MW, time: 11:00
# New Supply   818.0 MW, time: 7:00
# Load Growth  11.44 %, time: 11:00
# FL
# Total Energy supply added from current energy consumption = 1.8  TWh
# Current Peak 13360.0 MW, time: 12:00
# New Peak     13642.0 MW, time: 12:00
# New Supply   287.0 MW, time: 10:00
# Load Growth  2.11 %, time: 12:00
# 2038
# NY
# Total Energy supply added from current energy consumption = 14.8  TWh
# Current Peak 8181.0 MW, time: 11:00
# New Peak     10059.0 MW, time: 10:00
# New Supply   2267.0 MW, time: 7:00
# Load Growth  24.68 %, time: 10:00
# CA
# Total Energy supply added from current energy consumption = 16.4  TWh
# Current Peak 17267.0 MW, time: 12:00
# New Peak     18403.0 MW, time: 12:00
# New Supply   2753.0 MW, time: 6:00
# Load Growth  6.58 %, time: 12:00
# IL
# Total Energy supply added from current energy consumption = 10.3  TWh
# Current Peak 5403.0 MW, time: 12:00
# New Peak     6662.0 MW, time: 11:00
# New Supply   1655.0 MW, time: 7:00
# Load Growth  23.32 %, time: 11:00
# OH
# Total Energy supply added from current energy consumption = 8.8  TWh
# Current Peak 5586.0 MW, time: 11:00
# New Peak     6719.0 MW, time: 11:00
# New Supply   1437.0 MW, time: 7:00
# Load Growth  20.29 %, time: 11:00
# MI
# Total Energy supply added from current energy consumption = 8.7  TWh
# Current Peak 3529.0 MW, time: 12:00
# New Peak     4641.0 MW, time: 10:00
# New Supply   1439.0 MW, time: 7:00
# Load Growth  35.46 %, time: 10:00
# TX
# Total Energy supply added from current energy consumption = 5.2  TWh
# Current Peak 15412.0 MW, time: 12:00
# New Peak     16034.0 MW, time: 12:00
# New Supply   911.0 MW, time: 7:00
# Load Growth  4.04 %, time: 12:00
# PA
# Total Energy supply added from current energy consumption = 6.0  TWh
# Current Peak 5709.0 MW, time: 11:00
# New Peak     6476.0 MW, time: 11:00
# New Supply   960.0 MW, time: 7:00
# Load Growth  13.44 %, time: 11:00
# FL
# Total Energy supply added from current energy consumption = 2.1  TWh
# Current Peak 13360.0 MW, time: 12:00
# New Peak     13691.0 MW, time: 12:00
# New Supply   338.0 MW, time: 10:00
# Load Growth  2.48 %, time: 12:00
# 2039
# NY
# Total Energy supply added from current energy consumption = 14.9  TWh
# Current Peak 8181.0 MW, time: 11:00
# New Peak     10073.0 MW, time: 10:00
# New Supply   2283.0 MW, time: 7:00
# Load Growth  24.85 %, time: 10:00
# CA
# Total Energy supply added from current energy consumption = 16.5  TWh
# Current Peak 17267.0 MW, time: 12:00
# New Peak     18411.0 MW, time: 12:00
# New Supply   2773.0 MW, time: 6:00
# Load Growth  6.63 %, time: 12:00
# IL
# Total Energy supply added from current energy consumption = 11.6  TWh
# Current Peak 5403.0 MW, time: 12:00
# New Peak     6811.0 MW, time: 11:00
# New Supply   1850.0 MW, time: 7:00
# Load Growth  26.08 %, time: 11:00
# OH
# Total Energy supply added from current energy consumption = 9.9  TWh
# Current Peak 5586.0 MW, time: 11:00
# New Peak     6854.0 MW, time: 11:00
# New Supply   1607.0 MW, time: 7:00
# Load Growth  22.7 %, time: 11:00
# MI
# Total Energy supply added from current energy consumption = 9.8  TWh
# Current Peak 3529.0 MW, time: 12:00
# New Peak     4785.0 MW, time: 10:00
# New Supply   1610.0 MW, time: 7:00
# Load Growth  39.66 %, time: 10:00
# TX
# Total Energy supply added from current energy consumption = 5.8  TWh
# Current Peak 15412.0 MW, time: 12:00
# New Peak     16108.0 MW, time: 12:00
# New Supply   1019.0 MW, time: 7:00
# Load Growth  4.51 %, time: 12:00
# PA
# Total Energy supply added from current energy consumption = 6.7  TWh
# Current Peak 5709.0 MW, time: 11:00
# New Peak     6567.0 MW, time: 11:00
# New Supply   1074.0 MW, time: 7:00
# Load Growth  15.03 %, time: 11:00
# FL
# Total Energy supply added from current energy consumption = 2.3  TWh
# Current Peak 13360.0 MW, time: 12:00
# New Peak     13730.0 MW, time: 12:00
# New Supply   378.0 MW, time: 10:00
# Load Growth  2.77 %, time: 12:00
# 2040
# NY
# Total Energy supply added from current energy consumption = 14.9  TWh
# Current Peak 8181.0 MW, time: 11:00
# New Peak     10082.0 MW, time: 10:00
# New Supply   2293.0 MW, time: 7:00
# Load Growth  24.96 %, time: 10:00
# CA
# Total Energy supply added from current energy consumption = 16.6  TWh
# Current Peak 17267.0 MW, time: 12:00
# New Peak     18416.0 MW, time: 12:00
# New Supply   2785.0 MW, time: 6:00
# Load Growth  6.66 %, time: 12:00
# IL
# Total Energy supply added from current energy consumption = 12.5  TWh
# Current Peak 5403.0 MW, time: 12:00
# New Peak     6925.0 MW, time: 10:00
# New Supply   1993.0 MW, time: 7:00
# Load Growth  31.19 %, time: 10:00
# OH
# Total Energy supply added from current energy consumption = 10.7  TWh
# Current Peak 5586.0 MW, time: 11:00
# New Peak     6952.0 MW, time: 11:00
# New Supply   1731.0 MW, time: 7:00
# Load Growth  24.45 %, time: 11:00
# MI
# Total Energy supply added from current energy consumption = 10.5  TWh
# Current Peak 3529.0 MW, time: 12:00
# New Peak     4890.0 MW, time: 10:00
# New Supply   1734.0 MW, time: 7:00
# Load Growth  42.72 %, time: 10:00
# TX
# Total Energy supply added from current energy consumption = 6.2  TWh
# Current Peak 15412.0 MW, time: 12:00
# New Peak     16162.0 MW, time: 12:00
# New Supply   1098.0 MW, time: 7:00
# Load Growth  4.86 %, time: 12:00
# PA
# Total Energy supply added from current energy consumption = 7.2  TWh
# Current Peak 5709.0 MW, time: 11:00
# New Peak     6633.0 MW, time: 11:00
# New Supply   1157.0 MW, time: 7:00
# Load Growth  16.19 %, time: 11:00
# FL
# Total Energy supply added from current energy consumption = 2.5  TWh
# Current Peak 13360.0 MW, time: 12:00
# New Peak     13759.0 MW, time: 12:00
# New Supply   407.0 MW, time: 10:00
# Load Growth  2.99 %, time: 12:00
# 2041
# NY
# Total Energy supply added from current energy consumption = 15.0  TWh
# Current Peak 8181.0 MW, time: 11:00
# New Peak     10087.0 MW, time: 10:00
# New Supply   2299.0 MW, time: 7:00
# Load Growth  25.03 %, time: 10:00
# CA
# Total Energy supply added from current energy consumption = 16.6  TWh
# Current Peak 17267.0 MW, time: 12:00
# New Peak     18419.0 MW, time: 12:00
# New Supply   2792.0 MW, time: 6:00
# Load Growth  6.68 %, time: 12:00
# IL
# Total Energy supply added from current energy consumption = 13.1  TWh
# Current Peak 5403.0 MW, time: 12:00
# New Peak     7006.0 MW, time: 10:00
# New Supply   2092.0 MW, time: 7:00
# Load Growth  32.73 %, time: 10:00
# OH
# Total Energy supply added from current energy consumption = 11.2  TWh
# Current Peak 5586.0 MW, time: 11:00
# New Peak     7019.0 MW, time: 11:00
# New Supply   1816.0 MW, time: 7:00
# Load Growth  25.65 %, time: 11:00
# MI
# Total Energy supply added from current energy consumption = 11.1  TWh
# Current Peak 3529.0 MW, time: 12:00
# New Peak     4962.0 MW, time: 10:00
# New Supply   1820.0 MW, time: 7:00
# Load Growth  44.83 %, time: 10:00
# TX
# Total Energy supply added from current energy consumption = 6.5  TWh
# Current Peak 15412.0 MW, time: 12:00
# New Peak     16199.0 MW, time: 12:00
# New Supply   1152.0 MW, time: 7:00
# Load Growth  5.1 %, time: 12:00
# PA
# Total Energy supply added from current energy consumption = 7.6  TWh
# Current Peak 5709.0 MW, time: 11:00
# New Peak     6678.0 MW, time: 11:00
# New Supply   1214.0 MW, time: 7:00
# Load Growth  16.99 %, time: 11:00
# FL
# Total Energy supply added from current energy consumption = 2.6  TWh
# Current Peak 13360.0 MW, time: 12:00
# New Peak     13778.0 MW, time: 12:00
# New Supply   427.0 MW, time: 10:00
# Load Growth  3.13 %, time: 12:00
# 2042
# NY
# Total Energy supply added from current energy consumption = 15.0  TWh
# Current Peak 8181.0 MW, time: 11:00
# New Peak     10090.0 MW, time: 10:00
# New Supply   2303.0 MW, time: 7:00
# Load Growth  25.07 %, time: 10:00
# CA
# Total Energy supply added from current energy consumption = 16.7  TWh
# Current Peak 17267.0 MW, time: 12:00
# New Peak     18421.0 MW, time: 12:00
# New Supply   2797.0 MW, time: 6:00
# Load Growth  6.69 %, time: 12:00
# IL
# Total Energy supply added from current energy consumption = 13.5  TWh
# Current Peak 5403.0 MW, time: 12:00
# New Peak     7059.0 MW, time: 10:00
# New Supply   2156.0 MW, time: 7:00
# Load Growth  33.74 %, time: 10:00
# OH
# Total Energy supply added from current energy consumption = 11.5  TWh
# Current Peak 5586.0 MW, time: 11:00
# New Peak     7065.0 MW, time: 10:00
# New Supply   1872.0 MW, time: 7:00
# Load Growth  29.56 %, time: 10:00
# MI
# Total Energy supply added from current energy consumption = 11.4  TWh
# Current Peak 3529.0 MW, time: 12:00
# New Peak     5009.0 MW, time: 10:00
# New Supply   1876.0 MW, time: 7:00
# Load Growth  46.21 %, time: 10:00
# TX
# Total Energy supply added from current energy consumption = 6.7  TWh
# Current Peak 15412.0 MW, time: 12:00
# New Peak     16223.0 MW, time: 12:00
# New Supply   1187.0 MW, time: 7:00
# Load Growth  5.26 %, time: 12:00
# PA
# Total Energy supply added from current energy consumption = 7.8  TWh
# Current Peak 5709.0 MW, time: 11:00
# New Peak     6708.0 MW, time: 11:00
# New Supply   1251.0 MW, time: 7:00
# Load Growth  17.51 %, time: 11:00
# FL
# Total Energy supply added from current energy consumption = 2.7  TWh
# Current Peak 13360.0 MW, time: 12:00
# New Peak     13791.0 MW, time: 12:00
# New Supply   440.0 MW, time: 10:00
# Load Growth  3.23 %, time: 12:00
# 2043
# NY
# Total Energy supply added from current energy consumption = 15.0  TWh
# Current Peak 8181.0 MW, time: 11:00
# New Peak     10092.0 MW, time: 10:00
# New Supply   2305.0 MW, time: 7:00
# Load Growth  25.09 %, time: 10:00
# CA
# Total Energy supply added from current energy consumption = 16.7  TWh
# Current Peak 17267.0 MW, time: 12:00
# New Peak     18422.0 MW, time: 12:00
# New Supply   2800.0 MW, time: 6:00
# Load Growth  6.69 %, time: 12:00
# IL
# Total Energy supply added from current energy consumption = 13.7  TWh
# Current Peak 5403.0 MW, time: 12:00
# New Peak     7093.0 MW, time: 10:00
# New Supply   2197.0 MW, time: 7:00
# Load Growth  34.38 %, time: 10:00
# OH
# Total Energy supply added from current energy consumption = 11.7  TWh
# Current Peak 5586.0 MW, time: 11:00
# New Peak     7096.0 MW, time: 10:00
# New Supply   1908.0 MW, time: 7:00
# Load Growth  30.13 %, time: 10:00
# MI
# Total Energy supply added from current energy consumption = 11.6  TWh
# Current Peak 3529.0 MW, time: 12:00
# New Peak     5039.0 MW, time: 10:00
# New Supply   1911.0 MW, time: 7:00
# Load Growth  47.08 %, time: 10:00
# TX
# Total Energy supply added from current energy consumption = 6.9  TWh
# Current Peak 15412.0 MW, time: 12:00
# New Peak     16238.0 MW, time: 12:00
# New Supply   1210.0 MW, time: 7:00
# Load Growth  5.36 %, time: 12:00
# PA
# Total Energy supply added from current energy consumption = 8.0  TWh
# Current Peak 5709.0 MW, time: 11:00
# New Peak     6727.0 MW, time: 11:00
# New Supply   1275.0 MW, time: 7:00
# Load Growth  17.84 %, time: 11:00
# FL
# Total Energy supply added from current energy consumption = 2.7  TWh
# Current Peak 13360.0 MW, time: 12:00
# New Peak     13799.0 MW, time: 12:00
# New Supply   448.0 MW, time: 10:00
# Load Growth  3.29 %, time: 12:00
# 2044
# NY
# Total Energy supply added from current energy consumption = 15.0  TWh
# Current Peak 8181.0 MW, time: 11:00
# New Peak     10094.0 MW, time: 10:00
# New Supply   2306.0 MW, time: 7:00
# Load Growth  25.11 %, time: 10:00
# CA
# Total Energy supply added from current energy consumption = 16.7  TWh
# Current Peak 17267.0 MW, time: 12:00
# New Peak     18423.0 MW, time: 12:00
# New Supply   2801.0 MW, time: 6:00
# Load Growth  6.7 %, time: 12:00
# IL
# Total Energy supply added from current energy consumption = 13.9  TWh
# Current Peak 5403.0 MW, time: 12:00
# New Peak     7114.0 MW, time: 10:00
# New Supply   2223.0 MW, time: 7:00
# Load Growth  34.78 %, time: 10:00
# OH
# Total Energy supply added from current energy consumption = 11.9  TWh
# Current Peak 5586.0 MW, time: 11:00
# New Peak     7115.0 MW, time: 10:00
# New Supply   1930.0 MW, time: 7:00
# Load Growth  30.48 %, time: 10:00
# MI
# Total Energy supply added from current energy consumption = 11.8  TWh
# Current Peak 3529.0 MW, time: 12:00
# New Peak     5058.0 MW, time: 10:00
# New Supply   1934.0 MW, time: 7:00
# Load Growth  47.63 %, time: 10:00
# TX
# Total Energy supply added from current energy consumption = 7.0  TWh
# Current Peak 15412.0 MW, time: 12:00
# New Peak     16248.0 MW, time: 12:00
# New Supply   1224.0 MW, time: 7:00
# Load Growth  5.42 %, time: 12:00
# PA
# Total Energy supply added from current energy consumption = 8.1  TWh
# Current Peak 5709.0 MW, time: 11:00
# New Peak     6739.0 MW, time: 11:00
# New Supply   1290.0 MW, time: 7:00
# Load Growth  18.05 %, time: 11:00
# FL
# Total Energy supply added from current energy consumption = 2.8  TWh
# Current Peak 13360.0 MW, time: 12:00
# New Peak     13804.0 MW, time: 12:00
# New Supply   454.0 MW, time: 10:00
# Load Growth  3.33 %, time: 12:00
# 2045
# NY
# Total Energy supply added from current energy consumption = 15.0  TWh
# Current Peak 8181.0 MW, time: 11:00
# New Peak     10094.0 MW, time: 10:00
# New Supply   2307.0 MW, time: 7:00
# Load Growth  25.12 %, time: 10:00
# CA
# Total Energy supply added from current energy consumption = 16.7  TWh
# Current Peak 17267.0 MW, time: 12:00
# New Peak     18423.0 MW, time: 12:00
# New Supply   2802.0 MW, time: 6:00
# Load Growth  6.7 %, time: 12:00
# IL
# Total Energy supply added from current energy consumption = 14.0  TWh
# Current Peak 5403.0 MW, time: 12:00
# New Peak     7127.0 MW, time: 10:00
# New Supply   2238.0 MW, time: 7:00
# Load Growth  35.03 %, time: 10:00
# OH
# Total Energy supply added from current energy consumption = 12.0  TWh
# Current Peak 5586.0 MW, time: 11:00
# New Peak     7127.0 MW, time: 10:00
# New Supply   1944.0 MW, time: 7:00
# Load Growth  30.69 %, time: 10:00
# MI
# Total Energy supply added from current energy consumption = 11.8  TWh
# Current Peak 3529.0 MW, time: 12:00
# New Peak     5070.0 MW, time: 10:00
# New Supply   1947.0 MW, time: 7:00
# Load Growth  47.97 %, time: 10:00
# TX
# Total Energy supply added from current energy consumption = 7.0  TWh
# Current Peak 15412.0 MW, time: 12:00
# New Peak     16254.0 MW, time: 12:00
# New Supply   1233.0 MW, time: 7:00
# Load Growth  5.46 %, time: 12:00
# PA
# Total Energy supply added from current energy consumption = 8.1  TWh
# Current Peak 5709.0 MW, time: 11:00
# New Peak     6747.0 MW, time: 11:00
# New Supply   1299.0 MW, time: 7:00
# Load Growth  18.18 %, time: 11:00
# FL
# Total Energy supply added from current energy consumption = 2.8  TWh
# Current Peak 13360.0 MW, time: 12:00
# New Peak     13808.0 MW, time: 12:00
# New Supply   457.0 MW, time: 10:00
# Load Growth  3.35 %, time: 12:00
# 2046
# NY
# Total Energy supply added from current energy consumption = 15.0  TWh
# Current Peak 8181.0 MW, time: 11:00
# New Peak     10095.0 MW, time: 10:00
# New Supply   2308.0 MW, time: 7:00
# Load Growth  25.12 %, time: 10:00
# CA
# Total Energy supply added from current energy consumption = 16.7  TWh
# Current Peak 17267.0 MW, time: 12:00
# New Peak     18424.0 MW, time: 12:00
# New Supply   2803.0 MW, time: 6:00
# Load Growth  6.7 %, time: 12:00
# IL
# Total Energy supply added from current energy consumption = 14.1  TWh
# Current Peak 5403.0 MW, time: 12:00
# New Peak     7135.0 MW, time: 10:00
# New Supply   2248.0 MW, time: 7:00
# Load Growth  35.18 %, time: 10:00
# OH
# Total Energy supply added from current energy consumption = 12.0  TWh
# Current Peak 5586.0 MW, time: 11:00
# New Peak     7134.0 MW, time: 10:00
# New Supply   1952.0 MW, time: 7:00
# Load Growth  30.83 %, time: 10:00
# MI
# Total Energy supply added from current energy consumption = 11.9  TWh
# Current Peak 3529.0 MW, time: 12:00
# New Peak     5077.0 MW, time: 10:00
# New Supply   1956.0 MW, time: 7:00
# Load Growth  48.18 %, time: 10:00
# TX
# Total Energy supply added from current energy consumption = 7.0  TWh
# Current Peak 15412.0 MW, time: 12:00
# New Peak     16257.0 MW, time: 12:00
# New Supply   1238.0 MW, time: 7:00
# Load Growth  5.48 %, time: 12:00
# PA
# Total Energy supply added from current energy consumption = 8.2  TWh
# Current Peak 5709.0 MW, time: 11:00
# New Peak     6751.0 MW, time: 11:00
# New Supply   1305.0 MW, time: 7:00
# Load Growth  18.26 %, time: 11:00
# FL
# Total Energy supply added from current energy consumption = 2.8  TWh
# Current Peak 13360.0 MW, time: 12:00
# New Peak     13810.0 MW, time: 12:00
# New Supply   459.0 MW, time: 10:00
# Load Growth  3.37 %, time: 12:00
# 2047
# NY
# Total Energy supply added from current energy consumption = 15.0  TWh
# Current Peak 8181.0 MW, time: 11:00
# New Peak     10095.0 MW, time: 10:00
# New Supply   2308.0 MW, time: 7:00
# Load Growth  25.12 %, time: 10:00
# CA
# Total Energy supply added from current energy consumption = 16.7  TWh
# Current Peak 17267.0 MW, time: 12:00
# New Peak     18424.0 MW, time: 12:00
# New Supply   2803.0 MW, time: 6:00
# Load Growth  6.7 %, time: 12:00
# IL
# Total Energy supply added from current energy consumption = 14.1  TWh
# Current Peak 5403.0 MW, time: 12:00
# New Peak     7140.0 MW, time: 10:00
# New Supply   2254.0 MW, time: 7:00
# Load Growth  35.27 %, time: 10:00
# OH
# Total Energy supply added from current energy consumption = 12.0  TWh
# Current Peak 5586.0 MW, time: 11:00
# New Peak     7138.0 MW, time: 10:00
# New Supply   1957.0 MW, time: 7:00
# Load Growth  30.91 %, time: 10:00
# MI
# Total Energy supply added from current energy consumption = 11.9  TWh
# Current Peak 3529.0 MW, time: 12:00
# New Peak     5081.0 MW, time: 10:00
# New Supply   1961.0 MW, time: 7:00
# Load Growth  48.31 %, time: 10:00
# TX
# Total Energy supply added from current energy consumption = 7.1  TWh
# Current Peak 15412.0 MW, time: 12:00
# New Peak     16260.0 MW, time: 12:00
# New Supply   1242.0 MW, time: 7:00
# Load Growth  5.5 %, time: 12:00
# PA
# Total Energy supply added from current energy consumption = 8.2  TWh
# Current Peak 5709.0 MW, time: 11:00
# New Peak     6754.0 MW, time: 11:00
# New Supply   1308.0 MW, time: 7:00
# Load Growth  18.3 %, time: 11:00
# FL
# Total Energy supply added from current energy consumption = 2.8  TWh
# Current Peak 13360.0 MW, time: 12:00
# New Peak     13811.0 MW, time: 12:00
# New Supply   460.0 MW, time: 10:00
# Load Growth  3.38 %, time: 12:00
# 2048
# NY
# Total Energy supply added from current energy consumption = 15.0  TWh
# Current Peak 8181.0 MW, time: 11:00
# New Peak     10095.0 MW, time: 10:00
# New Supply   2308.0 MW, time: 7:00
# Load Growth  25.13 %, time: 10:00
# CA
# Total Energy supply added from current energy consumption = 16.7  TWh
# Current Peak 17267.0 MW, time: 12:00
# New Peak     18424.0 MW, time: 12:00
# New Supply   2803.0 MW, time: 6:00
# Load Growth  6.7 %, time: 12:00
# IL
# Total Energy supply added from current energy consumption = 14.1  TWh
# Current Peak 5403.0 MW, time: 12:00
# New Peak     7143.0 MW, time: 10:00
# New Supply   2258.0 MW, time: 7:00
# Load Growth  35.33 %, time: 10:00
# OH
# Total Energy supply added from current energy consumption = 12.1  TWh
# Current Peak 5586.0 MW, time: 11:00
# New Peak     7141.0 MW, time: 10:00
# New Supply   1961.0 MW, time: 7:00
# Load Growth  30.96 %, time: 10:00
# MI
# Total Energy supply added from current energy consumption = 11.9  TWh
# Current Peak 3529.0 MW, time: 12:00
# New Peak     5084.0 MW, time: 10:00
# New Supply   1964.0 MW, time: 7:00
# Load Growth  48.39 %, time: 10:00
# TX
# Total Energy supply added from current energy consumption = 7.1  TWh
# Current Peak 15412.0 MW, time: 12:00
# New Peak     16261.0 MW, time: 12:00
# New Supply   1244.0 MW, time: 7:00
# Load Growth  5.51 %, time: 12:00
# PA
# Total Energy supply added from current energy consumption = 8.2  TWh
# Current Peak 5709.0 MW, time: 11:00
# New Peak     6755.0 MW, time: 11:00
# New Supply   1310.0 MW, time: 7:00
# Load Growth  18.33 %, time: 11:00
# FL
# Total Energy supply added from current energy consumption = 2.8  TWh
# Current Peak 13360.0 MW, time: 12:00
# New Peak     13812.0 MW, time: 12:00
# New Supply   461.0 MW, time: 10:00
# Load Growth  3.38 %, time: 12:00
# 2049
# NY
# Total Energy supply added from current energy consumption = 15.0  TWh
# Current Peak 8181.0 MW, time: 11:00
# New Peak     10095.0 MW, time: 10:00
# New Supply   2308.0 MW, time: 7:00
# Load Growth  25.13 %, time: 10:00
# CA
# Total Energy supply added from current energy consumption = 16.7  TWh
# Current Peak 17267.0 MW, time: 12:00
# New Peak     18424.0 MW, time: 12:00
# New Supply   2804.0 MW, time: 6:00
# Load Growth  6.7 %, time: 12:00
# IL
# Total Energy supply added from current energy consumption = 14.1  TWh
# Current Peak 5403.0 MW, time: 12:00
# New Peak     7145.0 MW, time: 10:00
# New Supply   2260.0 MW, time: 7:00
# Load Growth  35.36 %, time: 10:00
# OH
# Total Energy supply added from current energy consumption = 12.1  TWh
# Current Peak 5586.0 MW, time: 11:00
# New Peak     7143.0 MW, time: 10:00
# New Supply   1963.0 MW, time: 7:00
# Load Growth  30.99 %, time: 10:00
# MI
# Total Energy supply added from current energy consumption = 11.9  TWh
# Current Peak 3529.0 MW, time: 12:00
# New Peak     5086.0 MW, time: 10:00
# New Supply   1966.0 MW, time: 7:00
# Load Growth  48.43 %, time: 10:00
# TX
# Total Energy supply added from current energy consumption = 7.1  TWh
# Current Peak 15412.0 MW, time: 12:00
# New Peak     16262.0 MW, time: 12:00
# New Supply   1245.0 MW, time: 7:00
# Load Growth  5.51 %, time: 12:00
# PA
# Total Energy supply added from current energy consumption = 8.2  TWh
# Current Peak 5709.0 MW, time: 11:00
# New Peak     6756.0 MW, time: 11:00
# New Supply   1312.0 MW, time: 7:00
# Load Growth  18.35 %, time: 11:00
# FL
# Total Energy supply added from current energy consumption = 2.8  TWh
# Current Peak 13360.0 MW, time: 12:00
# New Peak     13812.0 MW, time: 12:00
# New Supply   461.0 MW, time: 10:00
# Load Growth  3.39 %, time: 12:00
# 2050
# NY
# Total Energy supply added from current energy consumption = 15.0  TWh
# Current Peak 8181.0 MW, time: 11:00
# New Peak     10095.0 MW, time: 10:00
# New Supply   2308.0 MW, time: 7:00
# Load Growth  25.13 %, time: 10:00
# CA
# Total Energy supply added from current energy consumption = 16.7  TWh
# Current Peak 17267.0 MW, time: 12:00
# New Peak     18424.0 MW, time: 12:00
# New Supply   2804.0 MW, time: 6:00
# Load Growth  6.7 %, time: 12:00
# IL
# Total Energy supply added from current energy consumption = 14.1  TWh
# Current Peak 5403.0 MW, time: 12:00
# New Peak     7146.0 MW, time: 10:00
# New Supply   2261.0 MW, time: 7:00
# Load Growth  35.38 %, time: 10:00
# OH
# Total Energy supply added from current energy consumption = 12.1  TWh
# Current Peak 5586.0 MW, time: 11:00
# New Peak     7144.0 MW, time: 10:00
# New Supply   1964.0 MW, time: 7:00
# Load Growth  31.01 %, time: 10:00
# MI
# Total Energy supply added from current energy consumption = 12.0  TWh
# Current Peak 3529.0 MW, time: 12:00
# New Peak     5087.0 MW, time: 10:00
# New Supply   1967.0 MW, time: 7:00
# Load Growth  48.46 %, time: 10:00
# TX
# Total Energy supply added from current energy consumption = 7.1  TWh
# Current Peak 15412.0 MW, time: 12:00
# New Peak     16262.0 MW, time: 12:00
# New Supply   1245.0 MW, time: 7:00
# Load Growth  5.51 %, time: 12:00
# PA
# Total Energy supply added from current energy consumption = 8.2  TWh
# Current Peak 5709.0 MW, time: 11:00
# New Peak     6757.0 MW, time: 11:00
# New Supply   1312.0 MW, time: 7:00
# Load Growth  18.36 %, time: 11:00
# FL
# Total Energy supply added from current energy consumption = 2.8  TWh
# Current Peak 13360.0 MW, time: 12:00
# New Peak     13812.0 MW, time: 12:00
# New Supply   461.0 MW, time: 10:00
# Load Growth  3.39 %, time: 12:00

# %% [markdown]
# # Make plots of peaks/energy over years for each state

# %%
state_summary_list = {}

for state in com_states:
    print(state)
    
    state_summary_list[state] = {"New Peak" : [], "New Supply" : [], "Total Energy Added" : []}
    
    for study_year in year_range:
        print(study_year)
        str_study_year = str(study_year)
    
        state_summary_list[state]["New Peak"].append(results_comm[str_study_year][state]["New Peak"])
        state_summary_list[state]["New Supply"].append(results_comm[str_study_year][state]["New Supply"])
        state_summary_list[state]["Total Energy Added"].append(results_comm[str_study_year][state]["Total Energy Supply Added from Current Energy Consumption"])
# Out:
# NY
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2047
# 2048
# 2049
# 2050
# CA
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2047
# 2048
# 2049
# 2050
# IL
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2047
# 2048
# 2049
# 2050
# OH
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2047
# 2048
# 2049
# 2050
# MI
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2047
# 2048
# 2049
# 2050
# TX
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2047
# 2048
# 2049
# 2050
# PA
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2047
# 2048
# 2049
# 2050
# FL
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2047
# 2048
# 2049
# 2050

# %%
save_plots = False

# %%
for state in com_states:
    plt.plot(year_range, state_summary_list[state]["New Peak"], label=state)
plt.title(f"New Peak for Top States (Commercial)")   
plt.ylabel("Power (MW)")
plt.xlabel("Year")
plt.legend()

if save_plots:
    plt.savefig("com_new_peak_states.pdf", dpi=150)

plt.show()

# %%
for state in com_states:
    plt.plot(year_range, state_summary_list[state]["New Supply"], label=state)
plt.title(f"New Supply for Top States (Commercial)")   
plt.ylabel("Power (MW)")
plt.xlabel("Year")
plt.legend()

if save_plots:
    plt.savefig("com_new_supply_states.pdf", dpi=150)
    
plt.show()

# %%
for state in com_states:
    plt.plot(year_range, state_summary_list[state]["Total Energy Added"], label=state)
plt.title(f"Total Energy Supply Added for Top States (Commercial)")   
plt.ylabel("Energy (TWh)")
plt.xlabel("Year")
plt.legend()

if save_plots:
    plt.savefig("com_energy_supply_states.pdf", dpi=150)
    
plt.show()
